# %% [markdown]
# # Análisis de resultados

# %%
# Importaciones
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from scipy import stats
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Utils

# %%
SEED = 9603

bagging_model = [
  {
    'path_name' : 'rf', 
    'model_name' : 'RandomForestClassifier',
  },
  {
    'path_name' : 'dt', 
    'model_name' : 'DecisionTreeClassifier',
  },
  {
    'path_name' : 'mlp',
    'model_name' : 'MLPClassifier',
  },
  {
    'path_name' : 'knn',
    'model_name' : 'KNeighborsClassifier'
  },
]

# Número de modelos 
prng = np.random.RandomState(seed=SEED)
max_int32 = np.iinfo(np.int32).max
SEEDS_POR_MODELO = prng.randint(0, max_int32, size=len(bagging_model))
print(SEEDS_POR_MODELO)

iter_list   = ['Iteración 1', 'Iteración 2', 'Iteración 3', 'Iteración 4', 'Iteración 5', 'Iteración 6', 'Iteración 7', 'Iteración 8', 'Iteración 9', 'Iteración 10']
metric_list = ['Exac', 'Prec', 'Sens', 'F1', 'ms', 'AUC_PS']
label_list  = ['BENIGN', 'BOT', 'DDOS', 'DOS_GOLDENEYE', 'DOS_HULK', 'DOS_SLOWHTTPTEST', 'DOS_SLOWLORIS', 'FTP_PATATOR', 'PORTSCAN', 'SSH_PATATOR']
model_list  = ['RandomForestClassifier', 'DecisionTreeClassifier', 'MLPClassifier', 'KNeighborsClassifier', 'IDSBaggingClassifier']
# Out:
# [793494059 498241738 377997800 912782427]

# %%
# Resultados ordenados por métrica
df_results = pd.read_excel('DB/testing_results.xlsx')
df_results['iter'] = pd.Categorical(df_results['iter'], categories=iter_list, ordered=True)
df_results
# Out:
#              iter                   model  ...            ms    AUC_PS
# 0     Iteración 1  RandomForestClassifier  ...  71872.600005  0.999999
# 1     Iteración 1  RandomForestClassifier  ...  71872.600005  1.000000
# 2     Iteración 1  RandomForestClassifier  ...  71872.600005  1.000000
# 3     Iteración 1  RandomForestClassifier  ...  71872.600005  0.995983
# 4     Iteración 1  RandomForestClassifier  ...  71872.600005  0.999750
# ..            ...                     ...  ...           ...       ...
# 495  Iteración 10    IDSBaggingClassifier  ...    436.615200  0.984790
# 496  Iteración 10    IDSBaggingClassifier  ...    436.615200  1.000000
# 497  Iteración 10    IDSBaggingClassifier  ...    436.615200  1.000000
# 498  Iteración 10    IDSBaggingClassifier  ...    436.615200  0.999568
# 499  Iteración 10    IDSBaggingClassifier  ...    436.615200  1.000000
#
# [500 rows x 13 columns]

# %%
# Resultados ordenados por iteración
df_results_ordered = df_results.copy()
df_results_ordered = df_results_ordered.drop(
  ['TP', 'TN', 'FP', 'FN'], axis=1
).melt(
  id_vars=['iter', 'model', 'label'], var_name='metric', value_name='value'
).pivot(
  index=['metric', 'label', 'model'], columns='iter', values='value'
).reset_index()

# df_results_ordered.columns = ['{}_{}'.format(*col) if isinstance(col, tuple) else col for col in df_results_ordered.columns]
df_results_ordered['metric'] = pd.Categorical(df_results_ordered['metric'], categories=metric_list, ordered=True)
df_results_ordered['label'] = pd.Categorical(df_results_ordered['label'], categories=label_list, ordered=True)
df_results_ordered['model'] = pd.Categorical(df_results_ordered['model'], categories=model_list, ordered=True)

df_results_ordered = df_results_ordered.sort_values(by=['metric', 'label', 'model'])
df_results_ordered
# Out:
# iter  metric        label  ... Iteración 9  Iteración 10
# 54      Exac       BENIGN  ...    0.999353      0.998176
# 50      Exac       BENIGN  ...    0.997234      0.998823
# 53      Exac       BENIGN  ...    0.987641      0.989524
# 52      Exac       BENIGN  ...    0.998529      0.998117
# 51      Exac       BENIGN  ...    0.999529      0.999470
# ..       ...          ...  ...         ...           ...
# 49    AUC_PS  SSH_PATATOR  ...    1.000000      1.000000
# 45    AUC_PS  SSH_PATATOR  ...    0.986516      1.000000
# 48    AUC_PS  SSH_PATATOR  ...    1.000000      1.000000
# 47    AUC_PS  SSH_PATATOR  ...    0.972656      1.000000
# 46    AUC_PS  SSH_PATATOR  ...    0.999279      1.000000
#
# [300 rows x 13 columns]

# %%
with pd.ExcelWriter('output/df_results_ordered_by_iter.xlsx', engine='openpyxl') as writer:
  for metric in metric_list : 
    for label in label_list : 
      df_results_ordered[
        (df_results_ordered['metric'] == metric) &
        (df_results_ordered['label'] == label)
      ].to_excel(writer, sheet_name=f'{metric}_{label}', index=False)

# %%
df_results_ordered_by_model = df_results.copy()
df_results_ordered_by_model['model'] = pd.Categorical(df_results_ordered_by_model['model'], categories=model_list, ordered=True)
df_results_ordered_by_model = df_results_ordered_by_model.drop(
  ['TP', 'TN', 'FP', 'FN'], axis=1
).melt(
  id_vars=['iter', 'model', 'label'], var_name='metric', value_name='value'
).pivot(
  index=['metric', 'label', 'iter'], columns='model', values='value'
).reset_index()

# df_results_ordered.columns = ['{}_{}'.format(*col) if isinstance(col, tuple) else col for col in df_results_ordered.columns]
df_results_ordered_by_model['iter'] = pd.Categorical(df_results_ordered_by_model['iter'], categories=iter_list, ordered=True)
df_results_ordered_by_model['metric'] = pd.Categorical(df_results_ordered_by_model['metric'], categories=metric_list, ordered=True)
df_results_ordered_by_model['label'] = pd.Categorical(df_results_ordered_by_model['label'], categories=label_list, ordered=True)

df_results_ordered_by_model = df_results_ordered_by_model.sort_values(by=['metric', 'label', 'iter'])
df_results_ordered_by_model
# Out:
# model  metric        label  ... KNeighborsClassifier  IDSBaggingClassifier
# 100      Exac       BENIGN  ...             0.997999              0.999353
# 101      Exac       BENIGN  ...             0.998411              0.999353
# 102      Exac       BENIGN  ...             0.997999              0.999529
# 103      Exac       BENIGN  ...             0.998058              0.999588
# 104      Exac       BENIGN  ...             0.998352              0.999588
# ..        ...          ...  ...                  ...                   ...
# 95     AUC_PS  SSH_PATATOR  ...             1.000000              1.000000
# 96     AUC_PS  SSH_PATATOR  ...             1.000000              1.000000
# 97     AUC_PS  SSH_PATATOR  ...             1.000000              1.000000
# 98     AUC_PS  SSH_PATATOR  ...             0.972656              0.999279
# 99     AUC_PS  SSH_PATATOR  ...             1.000000              1.000000
#
# [600 rows x 8 columns]

# %%
with pd.ExcelWriter('output/df_results_ordered_by_model.xlsx', engine='openpyxl') as writer: 
  for metric in metric_list : 
    for label in label_list : 
      df_results_ordered_by_model[
        (df_results_ordered_by_model['metric'] == metric) &
        (df_results_ordered_by_model['label'] == label)
      ].to_excel(writer, sheet_name=f'{metric}_{label}', index=False)

# %%
df_results_ordered[
  (df_results_ordered['metric'] == 'Exac') & 
  (df_results_ordered['label'] == 'BENIGN') & 
  (df_results_ordered['model'] == 'RandomForestClassifier')
][iter_list].iloc[0].to_list()
# Out:
# [0.999411522391573,
#  0.9995292179132584,
#  0.9994703701524157,
#  0.9997646089566292,
#  0.9984111104572471,
#  0.9998234567174719,
#  0.9992938268698875,
#  0.9996469134349438,
#  0.99935263653484,
#  0.9981756120527306]

# %% [markdown]
# ## Test de Friedmann

# %%
""" Test de Friedman """
# H0 (hipótesis nula): No hay diferencias significativas entre los grupos comparados (los modelos rinden igual).
# H1 (hipótesis alternativa): Al menos un grupo difiere significativamente de los demás.
# Nivel de significancia = 0.05
# Si p <= nivel de significancia  ->  Se rechaza H0 (al menos una muestra difiere de las demás)

df_test_friedmann = pd.DataFrame(columns=["metric", "label", "gl", "stadistic", "p_value", "las muestras difieren?"])
nivel_significancia = 0.05

for metric in metric_list : 
  for label in label_list :
    lista_friedman = []
    for model in model_list : 
      mask = (
        (df_results_ordered['metric'] == metric) & 
        (df_results_ordered['label'] == label) & 
        (df_results_ordered['model'] == model)
      )
      muestra = df_results_ordered[mask][iter_list].iloc[0].to_list()
      lista_friedman.append(muestra)
    stat, p = stats.friedmanchisquare(*lista_friedman)
    df_test_friedmann.loc[len(df_test_friedmann)] = [
      metric,
      label,
      len(lista_friedman[0])-1,
      stat,
      p,
      p <= nivel_significancia 
    ]

df_test_friedmann
# Out:
#     metric             label  ...       p_value  las muestras difieren?
# 0     Exac            BENIGN  ...  8.551161e-07                    True
# 1     Exac               BOT  ...  4.496648e-07                    True
# 2     Exac              DDOS  ...  2.238784e-03                    True
# 3     Exac     DOS_GOLDENEYE  ...  8.680372e-07                    True
# 4     Exac          DOS_HULK  ...  8.323046e-06                    True
# 5     Exac  DOS_SLOWHTTPTEST  ...  5.069236e-06                    True
# 6     Exac     DOS_SLOWLORIS  ...  1.212024e-06                    True
# 7     Exac       FTP_PATATOR  ...  2.073236e-01                   False
# 8     Exac          PORTSCAN  ...  6.106124e-05                    True
# 9     Exac       SSH_PATATOR  ...  1.135103e-01                   False
# 10    Prec            BENIGN  ...  1.591550e-05                    True
# 11    Prec               BOT  ...  3.132670e-07                    True
# 12    Prec              DDOS  ...  1.898924e-01                   False
# 13    Prec     DOS_GOLDENEYE  ...  2.682465e-07                    True
# 14    Prec          DOS_HULK  ...  1.435429e-04                    True
# 15    Prec  DOS_SLOWHTTPTEST  ...  8.975030e-06                    True
# 16    Prec     DOS_SLOWLORIS  ...  5.005499e-07                    True
# 17    Prec       FTP_PATATOR  ...  6.356442e-02                   False
# 18    Prec          PORTSCAN  ...  7.276128e-06                    True
# 19    Prec       SSH_PATATOR  ...  4.755124e-02                    True
# 20    Sens            BENIGN  ...  2.357939e-06                    True
# 21    Sens               BOT  ...  1.991483e-01                   False
# 22    Sens              DDOS  ...  2.127922e-03                    True
# 23    Sens     DOS_GOLDENEYE  ...  1.293306e-03                    True
# 24    Sens          DOS_HULK  ...  4.870472e-06                    True
# 25    Sens  DOS_SLOWHTTPTEST  ...  1.932530e-01                   False
# 26    Sens     DOS_SLOWLORIS  ...  1.328471e-05                    True
# 27    Sens       FTP_PATATOR  ...  2.800467e-01                   False
# 28    Sens          PORTSCAN  ...  2.686444e-04                    True
# 29    Sens       SSH_PATATOR  ...  8.321188e-02                   False
# 30      F1            BENIGN  ...  8.345967e-07                    True
# 31      F1               BOT  ...  8.772285e-07                    True
# 32      F1              DDOS  ...  1.891645e-03                    True
# 33      F1     DOS_GOLDENEYE  ...  1.913098e-06                    True
# 34      F1          DOS_HULK  ...  7.371202e-06                    True
# 35      F1  DOS_SLOWHTTPTEST  ...  7.064361e-06                    True
# 36      F1     DOS_SLOWLORIS  ...  1.212024e-06                    True
# 37      F1       FTP_PATATOR  ...  2.073236e-01                   False
# 38      F1          PORTSCAN  ...  1.171773e-04                    True
# 39      F1       SSH_PATATOR  ...  1.166666e-01                   False
# 40      ms            BENIGN  ...  4.328423e-08                    True
# 41      ms               BOT  ...  4.328423e-08                    True
# 42      ms              DDOS  ...  4.328423e-08                    True
# 43      ms     DOS_GOLDENEYE  ...  4.328423e-08                    True
# 44      ms          DOS_HULK  ...  4.328423e-08                    True
# 45      ms  DOS_SLOWHTTPTEST  ...  4.328423e-08                    True
# 46      ms     DOS_SLOWLORIS  ...  4.328423e-08                    True
# 47      ms       FTP_PATATOR  ...  4.328423e-08                    True
# 48      ms          PORTSCAN  ...  4.328423e-08                    True
# 49      ms       SSH_PATATOR  ...  4.328423e-08                    True
# 50  AUC_PS            BENIGN  ...  2.394097e-07                    True
# 51  AUC_PS               BOT  ...  1.608440e-04                    True
# 52  AUC_PS              DDOS  ...  2.456597e-04                    True
# 53  AUC_PS     DOS_GOLDENEYE  ...  4.389013e-07                    True
# 54  AUC_PS          DOS_HULK  ...  4.734067e-07                    True
# 55  AUC_PS  DOS_SLOWHTTPTEST  ...  1.940754e-05                    True
# 56  AUC_PS     DOS_SLOWLORIS  ...  9.847922e-07                    True
# 57  AUC_PS       FTP_PATATOR  ...  1.707285e-02                    True
# 58  AUC_PS          PORTSCAN  ...  3.005331e-05                    True
# 59  AUC_PS       SSH_PATATOR  ...  6.670912e-02                   False
#
# [60 rows x 6 columns]

# %%
df_results_ordered
# Out:
# iter  metric        label  ... Iteración 9  Iteración 10
# 54      Exac       BENIGN  ...    0.999353      0.998176
# 50      Exac       BENIGN  ...    0.997234      0.998823
# 53      Exac       BENIGN  ...    0.987641      0.989524
# 52      Exac       BENIGN  ...    0.998529      0.998117
# 51      Exac       BENIGN  ...    0.999529      0.999470
# ..       ...          ...  ...         ...           ...
# 49    AUC_PS  SSH_PATATOR  ...    1.000000      1.000000
# 45    AUC_PS  SSH_PATATOR  ...    0.986516      1.000000
# 48    AUC_PS  SSH_PATATOR  ...    1.000000      1.000000
# 47    AUC_PS  SSH_PATATOR  ...    0.972656      1.000000
# 46    AUC_PS  SSH_PATATOR  ...    0.999279      1.000000
#
# [300 rows x 13 columns]

# %% [markdown]
# ## Test de Shapiro-Wilk

# %%
list_models = ['RandomForestClassifier', 'DecisionTreeClassifier', 'MLPClassifier', 'KNeighborsClassifier']
bagging_model_name = 'IDSBaggingClassifier'

# %%
""" Test de Shapiro Wilk """
# H0 (hipótesis nula): Los datos provienen de una distribución normal
# H1 (hipótesis alternativa): Los datos no provienen de una distribución normal
# Nivel de significancia = 0.05
# Si p < nivel de significancia  ->  Los datos no provienen de una distribución normal
df_shapiro_wilk = pd.DataFrame(columns=["metric", "label", "model", "stadistic", "p_value", "es fiable?"])
nivel_significancia_normalidad = 0.05

for metric in metric_list : 
  for label in label_list :
    for model in [bagging_model_name]+list_models :
      muestra = df_results_ordered[
        (df_results_ordered['metric'] == metric) & 
        (df_results_ordered['label'] == label) & 
        (df_results_ordered['model'] == model)
      ][iter_list].iloc[0].to_list()

      fiable = True
      if np.ptp(muestra) > 0 : 
        fiable = True
      else : 
        print(f'Los resultados de la prueba en {metric}, {label} y {model} no son fiables porque tienen varianza 0')
        fiable = False

      stat, p = stats.shapiro(muestra)

      df_shapiro_wilk.loc[len(df_shapiro_wilk)] = [
        metric,
        label,
        model,
        stat,
        p,
        fiable
      ]
reject, p_corrected, _, _ = multipletests(
  df_shapiro_wilk['p_value'].to_list(),
  alpha=nivel_significancia_normalidad,
  method='holm'
) 

df_shapiro_wilk['p_corrected'] = p_corrected
df_shapiro_wilk['reject'] = reject
df_shapiro_wilk[df_shapiro_wilk['reject'] & df_shapiro_wilk['es fiable?']]
# Out:
# Los resultados de la prueba en Prec, SSH_PATATOR y IDSBaggingClassifier no son fiables porque tienen varianza 0
# Los resultados de la prueba en Prec, SSH_PATATOR y RandomForestClassifier no son fiables porque tienen varianza 0
# Los resultados de la prueba en Sens, DDOS y DecisionTreeClassifier no son fiables porque tienen varianza 0
# Los resultados de la prueba en Sens, FTP_PATATOR y IDSBaggingClassifier no son fiables porque tienen varianza 0
# Los resultados de la prueba en AUC_PS, DDOS y IDSBaggingClassifier no son fiables porque tienen varianza 0
# Los resultados de la prueba en AUC_PS, DDOS y RandomForestClassifier no son fiables porque tienen varianza 0
# Los resultados de la prueba en AUC_PS, FTP_PATATOR y IDSBaggingClassifier no son fiables porque tienen varianza 0
# Los resultados de la prueba en AUC_PS, FTP_PATATOR y RandomForestClassifier no son fiables porque tienen varianza 0
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
#      metric        label  ... p_corrected  reject
# 6      Exac          BOT  ...    0.012019    True
# 10     Exac         DDOS  ...    0.012019    True
# 11     Exac         DDOS  ...    0.002244    True
# 12     Exac         DDOS  ...    0.000030    True
# 35     Exac  FTP_PATATOR  ...    0.000030    True
# ..      ...          ...  ...         ...     ...
# 290  AUC_PS     PORTSCAN  ...    0.000034    True
# 291  AUC_PS     PORTSCAN  ...    0.006638    True
# 295  AUC_PS  SSH_PATATOR  ...    0.000030    True
# 296  AUC_PS  SSH_PATATOR  ...    0.000085    True
# 299  AUC_PS  SSH_PATATOR  ...    0.002128    True
#
# [70 rows x 8 columns]

# %%
""" Test de Shapiro Wilk """
# H0 (hipótesis nula): Los datos provienen de una distribución normal
# H1 (hipótesis alternativa): Los datos no provienen de una distribución normal
# Nivel de significancia = 0.05
# Si p < nivel de significancia  ->  Los datos no provienen de una distribución normal
df_shapiro_wilk = pd.DataFrame(columns=["metric", "label", "model", "difference", "stadistic", "p_value", "es fiable?"])
nivel_significancia_normalidad = 0.05

for metric in metric_list : 
  for label in label_list :
    mask = (df_results_ordered['metric'] == metric) & (df_results_ordered['label'] == label)
    bagging_mask = mask & (df_results_ordered['model'] == bagging_model_name)
    muestra_bagging = df_results_ordered[bagging_mask][iter_list].iloc[0]
    for model in list_models :
      model_mask = mask & (df_results_ordered['model'] == model)
      muestra = df_results_ordered[model_mask][iter_list].iloc[0]
      muestra_diferencia = muestra_bagging-muestra
      fiable = True
      if np.ptp(muestra_diferencia) > 0 : 
        fiable = True
      else : 
        print(f'Los resultados de la prueba en {metric}, {label} y {model} no son fiables porque tienen varianza 0')
        fiable = False

      stat, p = stats.shapiro(muestra_diferencia.to_list())

      df_shapiro_wilk.loc[len(df_shapiro_wilk)] = [
        metric,
        label,
        model,
        f'{bagging_model_name} - {model}',
        stat,
        p,
        fiable,
      ]
reject, p_corrected, _, _ = multipletests(
  df_shapiro_wilk['p_value'].to_list(),
  alpha=nivel_significancia_normalidad,
  method='holm'
) 

df_shapiro_wilk['p_corrected'] = p_corrected
df_shapiro_wilk['reject'] = reject
# df_shapiro_wilk
df_shapiro_wilk['test'] = np.where(
    (~df_shapiro_wilk['reject']) & (df_shapiro_wilk['es fiable?']),
    'T de Student',
    'Wilcoxon'
)
# df_shapiro_wilk
df_shapiro_wilk[['metric', 'label', 'model', 'es fiable?', 'reject', 'difference', 'stadistic', 'p_value', 'p_corrected', 'test']]
# Out:
# Los resultados de la prueba en Prec, FTP_PATATOR y RandomForestClassifier no son fiables porque tienen varianza 0
# Los resultados de la prueba en Prec, SSH_PATATOR y RandomForestClassifier no son fiables porque tienen varianza 0
# Los resultados de la prueba en Sens, BOT y DecisionTreeClassifier no son fiables porque tienen varianza 0
# Los resultados de la prueba en AUC_PS, DDOS y RandomForestClassifier no son fiables porque tienen varianza 0
# Los resultados de la prueba en AUC_PS, FTP_PATATOR y RandomForestClassifier no son fiables porque tienen varianza 0
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
#      metric        label  ... p_corrected          test
# 0      Exac       BENIGN  ...    1.000000  T de Student
# 1      Exac       BENIGN  ...    1.000000  T de Student
# 2      Exac       BENIGN  ...    1.000000  T de Student
# 3      Exac       BENIGN  ...    1.000000  T de Student
# 4      Exac          BOT  ...    0.992008  T de Student
# ..      ...          ...  ...         ...           ...
# 235  AUC_PS     PORTSCAN  ...    1.000000  T de Student
# 236  AUC_PS  SSH_PATATOR  ...    0.001276      Wilcoxon
# 237  AUC_PS  SSH_PATATOR  ...    1.000000  T de Student
# 238  AUC_PS  SSH_PATATOR  ...    0.000024      Wilcoxon
# 239  AUC_PS  SSH_PATATOR  ...    0.001876      Wilcoxon
#
# [240 rows x 10 columns]

# %%
""" Test T de Student unilateral """
# H0 (hipótesis nula): El metamodelo de ensamble Bagging tiene resultados iguales o menores a la instancia evaluada
# H1 (hipótesis alternativa): El metamodelo de ensamble Bagging tiene mejores resultados que la instancia evaluada
# Nivel de significancia = 0.05
# Si p < nivel de significancia  ->  Se acepta la hipótesis nula
""" Test Wilcoxon """
# H0 (hipótesis nula): El metamodelo de ensamble Bagging tiene resultados iguales o menores a la instancia evaluada
# H1 (hipótesis alternativa): El metamodelo de ensamble Bagging tiene mejores resultados que la instancia evaluada
# Nivel de significancia = 0.05
# Si p < nivel de significancia  ->  Se acepta la hipótesis nula
df_prueba_estadistica_diferencias_significativas = pd.DataFrame(columns=['metric', 'label', 'model', 'comparison', 'test', 'stat', 'p_value'])
nivel_significancia_diferencias_significativas = 0.05
for metric in metric_list : 
  for label in label_list :
    mask = (df_results_ordered['metric'] == metric) & (df_results_ordered['label'] == label)
    bagging_mask = mask & (df_results_ordered['model'] == bagging_model_name)
    muestra_bagging = df_results_ordered[bagging_mask][iter_list].iloc[0]
    for model in list_models :
      model_mask = mask & (df_results_ordered['model'] == model)
      muestra = df_results_ordered[model_mask][iter_list].iloc[0]
      test = df_shapiro_wilk[
        (df_shapiro_wilk['metric'] == metric) & 
        (df_shapiro_wilk['label'] == label) & 
        (df_shapiro_wilk['model'] == model)
      ]['test'].iloc[0]
      if test == 'T de Student' : 
        stat, p_value = stats.ttest_rel(muestra_bagging, muestra, alternative='greater')
        df_prueba_estadistica_diferencias_significativas.loc[len(df_prueba_estadistica_diferencias_significativas)] = [
          metric,
          label,
          model,
          f'{bagging_model_name} > {model}',
          test,
          stat,
          p_value
        ]
      elif test == 'Wilcoxon' : 
        stat, p_value = stats.wilcoxon(muestra_bagging, muestra, alternative='greater')
        df_prueba_estadistica_diferencias_significativas.loc[len(df_prueba_estadistica_diferencias_significativas)] = [
          metric,
          label,
          model,
          f'{bagging_model_name} > {model}',
          test,
          stat,
          p_value
        ]
reject, p_corrected, _, _ = multipletests(
  df_prueba_estadistica_diferencias_significativas['p_value'].to_list(),
  alpha=nivel_significancia_diferencias_significativas,
  method='holm'
) 
df_prueba_estadistica_diferencias_significativas['p_corrected'] = p_corrected
df_prueba_estadistica_diferencias_significativas['reject'] = reject
df_prueba_estadistica_diferencias_significativas
# Out:
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_wilcoxon.py:172: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_wilcoxon.py:172: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_wilcoxon.py:172: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_wilcoxon.py:172: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\scipy\stats\_wilcoxon.py:172: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
#      metric        label  ...   p_corrected reject
# 0      Exac       BENIGN  ...  1.000000e+00  False
# 1      Exac       BENIGN  ...  9.673355e-02  False
# 2      Exac       BENIGN  ...  5.145805e-09   True
# 3      Exac       BENIGN  ...  2.471403e-05   True
# 4      Exac          BOT  ...  1.000000e+00  False
# ..      ...          ...  ...           ...    ...
# 235  AUC_PS     PORTSCAN  ...  1.000000e+00  False
# 236  AUC_PS  SSH_PATATOR  ...  1.000000e+00  False
# 237  AUC_PS  SSH_PATATOR  ...  1.000000e+00  False
# 238  AUC_PS  SSH_PATATOR  ...  1.000000e+00  False
# 239  AUC_PS  SSH_PATATOR  ...  1.000000e+00  False
#
# [240 rows x 9 columns]

# %%
df_prueba_estadistica = pd.DataFrame(columns=["metric", "label", "model", "models", "prueba"])

for metric in metric_list : 
  for label in label_list :
    mask = (df_shapiro_wilk['metric'] == metric) & (df_shapiro_wilk['label'] == label)
    bagging_mask = mask & (df_shapiro_wilk['model'] == bagging_model_name)
    bagging_is_normal = df_shapiro_wilk[bagging_mask]['es fiable?'] & ~df_shapiro_wilk[bagging_mask]['reject']
    print('Bagging : ', bagging_is_normal)
    for model in list_models :
      model_mask = mask & (df_shapiro_wilk['model'] == model)
      model_is_normal = df_shapiro_wilk[model_mask]['es fiable?'] & ~df_shapiro_wilk[model_mask]['reject']
      print(model, ':', model_is_normal)
      df_prueba_estadistica.loc[len(df_prueba_estadistica)] = [
        metric,
        label,
        model,
        f'{bagging_model_name} != {model}',
        'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
      ]
df_prueba_estadistica[df_prueba_estadistica['prueba'] == 'T_Student']
# Out:
# Bagging :  0    True
# dtype: bool
# RandomForestClassifier : 1    True
# dtype: bool
# DecisionTreeClassifier : 2    True
# dtype: bool
# MLPClassifier : 3    True
# dtype: bool
# KNeighborsClassifier : 4    True
# dtype: bool
# Bagging :  5    True
# dtype: bool
# RandomForestClassifier : 6    False
# dtype: bool
# DecisionTreeClassifier : 7    True
# dtype: bool
# MLPClassifier : 8    True
# dtype: bool
# KNeighborsClassifier : 9    True
# dtype: bool
# Bagging :  10    False
# dtype: bool
# RandomForestClassifier : 11    False
# dtype: bool
# DecisionTreeClassifier : 12    False
# dtype: bool
# MLPClassifier : 13    True
# dtype: bool
# KNeighborsClassifier : 14    True
# dtype: bool
# Bagging :  15    True
# dtype: bool
# RandomForestClassifier : 16    True
# dtype: bool
# DecisionTreeClassifier : 17    True
# dtype: bool
# MLPClassifier : 18    True
# dtype: bool
# KNeighborsClassifier : 19    True
# dtype: bool
# Bagging :  20    True
# dtype: bool
# RandomForestClassifier : 21    True
# dtype: bool
# DecisionTreeClassifier : 22    True
# dtype: bool
# MLPClassifier : 23    True
# dtype: bool
# KNeighborsClassifier : 24    True
# dtype: bool
# Bagging :  25    True
# dtype: bool
# RandomForestClassifier : 26    True
# dtype: bool
# DecisionTreeClassifier : 27    True
# dtype: bool
# MLPClassifier : 28    True
# dtype: bool
# KNeighborsClassifier : 29    True
# dtype: bool
# Bagging :  30    True
# dtype: bool
# RandomForestClassifier : 31    True
# dtype: bool
# DecisionTreeClassifier : 32    True
# dtype: bool
# MLPClassifier : 33    True
# dtype: bool
# KNeighborsClassifier : 34    True
# dtype: bool
# Bagging :  35    False
# dtype: bool
# RandomForestClassifier : 36    False
# dtype: bool
# DecisionTreeClassifier : 37    False
# dtype: bool
# MLPClassifier : 38    True
# dtype: bool
# KNeighborsClassifier : 39    True
# dtype: bool
# Bagging :  40    True
# dtype: bool
# RandomForestClassifier : 41    False
# dtype: bool
# DecisionTreeClassifier : 42    False
# dtype: bool
# MLPClassifier : 43    True
# dtype: bool
# KNeighborsClassifier : 44    True
# dtype: bool
# Bagging :  45    False
# dtype: bool
# RandomForestClassifier : 46    False
# dtype: bool
# DecisionTreeClassifier : 47    True
# dtype: bool
# MLPClassifier : 48    True
# dtype: bool
# KNeighborsClassifier : 49    False
# dtype: bool
# Bagging :  50    True
# dtype: bool
# RandomForestClassifier : 51    True
# dtype: bool
# DecisionTreeClassifier : 52    True
# dtype: bool
# MLPClassifier : 53    True
# dtype: bool
# KNeighborsClassifier : 54    True
# dtype: bool
# Bagging :  55    True
# dtype: bool
# RandomForestClassifier : 56    False
# dtype: bool
# DecisionTreeClassifier : 57    True
# dtype: bool
# MLPClassifier : 58    True
# dtype: bool
# KNeighborsClassifier : 59    True
# dtype: bool
# Bagging :  60    False
# dtype: bool
# RandomForestClassifier : 61    False
# dtype: bool
# DecisionTreeClassifier : 62    False
# dtype: bool
# MLPClassifier : 63    False
# dtype: bool
# KNeighborsClassifier : 64    False
# dtype: bool
# Bagging :  65    True
# dtype: bool
# RandomForestClassifier : 66    True
# dtype: bool
# DecisionTreeClassifier : 67    True
# dtype: bool
# MLPClassifier : 68    True
# dtype: bool
# KNeighborsClassifier : 69    True
# dtype: bool
# Bagging :  70    True
# dtype: bool
# RandomForestClassifier : 71    True
# dtype: bool
# DecisionTreeClassifier : 72    True
# dtype: bool
# MLPClassifier : 73    True
# dtype: bool
# KNeighborsClassifier : 74    True
# dtype: bool
# Bagging :  75    True
# dtype: bool
# RandomForestClassifier : 76    False
# dtype: bool
# DecisionTreeClassifier : 77    True
# dtype: bool
# MLPClassifier : 78    True
# dtype: bool
# KNeighborsClassifier : 79    True
# dtype: bool
# Bagging :  80    True
# dtype: bool
# RandomForestClassifier : 81    False
# dtype: bool
# DecisionTreeClassifier : 82    True
# dtype: bool
# MLPClassifier : 83    True
# dtype: bool
# KNeighborsClassifier : 84    True
# dtype: bool
# Bagging :  85    False
# dtype: bool
# RandomForestClassifier : 86    False
# dtype: bool
# DecisionTreeClassifier : 87    False
# dtype: bool
# MLPClassifier : 88    True
# dtype: bool
# KNeighborsClassifier : 89    True
# dtype: bool
# Bagging :  90    False
# dtype: bool
# RandomForestClassifier : 91    False
# dtype: bool
# DecisionTreeClassifier : 92    False
# dtype: bool
# MLPClassifier : 93    True
# dtype: bool
# KNeighborsClassifier : 94    False
# dtype: bool
# Bagging :  95    False
# dtype: bool
# RandomForestClassifier : 96    False
# dtype: bool
# DecisionTreeClassifier : 97    False
# dtype: bool
# MLPClassifier : 98    True
# dtype: bool
# KNeighborsClassifier : 99    False
# dtype: bool
# Bagging :  100    True
# dtype: bool
# RandomForestClassifier : 101    True
# dtype: bool
# DecisionTreeClassifier : 102    True
# dtype: bool
# MLPClassifier : 103    True
# dtype: bool
# KNeighborsClassifier : 104    True
# dtype: bool
# Bagging :  105    False
# dtype: bool
# RandomForestClassifier : 106    False
# dtype: bool
# DecisionTreeClassifier : 107    False
# dtype: bool
# MLPClassifier : 108    False
# dtype: bool
# KNeighborsClassifier : 109    False
# dtype: bool
# Bagging :  110    False
# dtype: bool
# RandomForestClassifier : 111    False
# dtype: bool
# DecisionTreeClassifier : 112    False
# dtype: bool
# MLPClassifier : 113    False
# dtype: bool
# KNeighborsClassifier : 114    True
# dtype: bool
# Bagging :  115    True
# dtype: bool
# RandomForestClassifier : 116    True
# dtype: bool
# DecisionTreeClassifier : 117    True
# dtype: bool
# MLPClassifier : 118    True
# dtype: bool
# KNeighborsClassifier : 119    True
# dtype: bool
# Bagging :  120    True
# dtype: bool
# RandomForestClassifier : 121    True
# dtype: bool
# DecisionTreeClassifier : 122    True
# dtype: bool
# MLPClassifier : 123    True
# dtype: bool
# KNeighborsClassifier : 124    True
# dtype: bool
# Bagging :  125    True
# dtype: bool
# RandomForestClassifier : 126    True
# dtype: bool
# DecisionTreeClassifier : 127    True
# dtype: bool
# MLPClassifier : 128    True
# dtype: bool
# KNeighborsClassifier : 129    True
# dtype: bool
# Bagging :  130    False
# dtype: bool
# RandomForestClassifier : 131    True
# dtype: bool
# DecisionTreeClassifier : 132    True
# dtype: bool
# MLPClassifier : 133    True
# dtype: bool
# KNeighborsClassifier : 134    True
# dtype: bool
# Bagging :  135    False
# dtype: bool
# RandomForestClassifier : 136    False
# dtype: bool
# DecisionTreeClassifier : 137    False
# dtype: bool
# MLPClassifier : 138    True
# dtype: bool
# KNeighborsClassifier : 139    False
# dtype: bool
# Bagging :  140    True
# dtype: bool
# RandomForestClassifier : 141    True
# dtype: bool
# DecisionTreeClassifier : 142    False
# dtype: bool
# MLPClassifier : 143    True
# dtype: bool
# KNeighborsClassifier : 144    True
# dtype: bool
# Bagging :  145    False
# dtype: bool
# RandomForestClassifier : 146    False
# dtype: bool
# DecisionTreeClassifier : 147    True
# dtype: bool
# MLPClassifier : 148    False
# dtype: bool
# KNeighborsClassifier : 149    False
# dtype: bool
# Bagging :  150    True
# dtype: bool
# RandomForestClassifier : 151    True
# dtype: bool
# DecisionTreeClassifier : 152    True
# dtype: bool
# MLPClassifier : 153    True
# dtype: bool
# KNeighborsClassifier : 154    True
# dtype: bool
# Bagging :  155    True
# dtype: bool
# RandomForestClassifier : 156    False
# dtype: bool
# DecisionTreeClassifier : 157    True
# dtype: bool
# MLPClassifier : 158    True
# dtype: bool
# KNeighborsClassifier : 159    True
# dtype: bool
# Bagging :  160    False
# dtype: bool
# RandomForestClassifier : 161    False
# dtype: bool
# DecisionTreeClassifier : 162    False
# dtype: bool
# MLPClassifier : 163    True
# dtype: bool
# KNeighborsClassifier : 164    True
# dtype: bool
# Bagging :  165    True
# dtype: bool
# RandomForestClassifier : 166    True
# dtype: bool
# DecisionTreeClassifier : 167    True
# dtype: bool
# MLPClassifier : 168    True
# dtype: bool
# KNeighborsClassifier : 169    True
# dtype: bool
# Bagging :  170    True
# dtype: bool
# RandomForestClassifier : 171    True
# dtype: bool
# DecisionTreeClassifier : 172    True
# dtype: bool
# MLPClassifier : 173    True
# dtype: bool
# KNeighborsClassifier : 174    True
# dtype: bool
# Bagging :  175    True
# dtype: bool
# RandomForestClassifier : 176    True
# dtype: bool
# DecisionTreeClassifier : 177    True
# dtype: bool
# MLPClassifier : 178    True
# dtype: bool
# KNeighborsClassifier : 179    True
# dtype: bool
# Bagging :  180    True
# dtype: bool
# RandomForestClassifier : 181    True
# dtype: bool
# DecisionTreeClassifier : 182    True
# dtype: bool
# MLPClassifier : 183    True
# dtype: bool
# KNeighborsClassifier : 184    True
# dtype: bool
# Bagging :  185    False
# dtype: bool
# RandomForestClassifier : 186    False
# dtype: bool
# DecisionTreeClassifier : 187    True
# dtype: bool
# MLPClassifier : 188    True
# dtype: bool
# KNeighborsClassifier : 189    True
# dtype: bool
# Bagging :  190    True
# dtype: bool
# RandomForestClassifier : 191    False
# dtype: bool
# DecisionTreeClassifier : 192    False
# dtype: bool
# MLPClassifier : 193    True
# dtype: bool
# KNeighborsClassifier : 194    True
# dtype: bool
# Bagging :  195    False
# dtype: bool
# RandomForestClassifier : 196    False
# dtype: bool
# DecisionTreeClassifier : 197    True
# dtype: bool
# MLPClassifier : 198    True
# dtype: bool
# KNeighborsClassifier : 199    False
# dtype: bool
# Bagging :  200    True
# dtype: bool
# RandomForestClassifier : 201    True
# dtype: bool
# DecisionTreeClassifier : 202    True
# dtype: bool
# MLPClassifier : 203    True
# dtype: bool
# KNeighborsClassifier : 204    True
# dtype: bool
# Bagging :  205    True
# dtype: bool
# RandomForestClassifier : 206    True
# dtype: bool
# DecisionTreeClassifier : 207    True
# dtype: bool
# MLPClassifier : 208    True
# dtype: bool
# KNeighborsClassifier : 209    True
# dtype: bool
# Bagging :  210    True
# dtype: bool
# RandomForestClassifier : 211    True
# dtype: bool
# DecisionTreeClassifier : 212    True
# dtype: bool
# MLPClassifier : 213    True
# dtype: bool
# KNeighborsClassifier : 214    True
# dtype: bool
# Bagging :  215    True
# dtype: bool
# RandomForestClassifier : 216    True
# dtype: bool
# DecisionTreeClassifier : 217    True
# dtype: bool
# MLPClassifier : 218    True
# dtype: bool
# KNeighborsClassifier : 219    True
# dtype: bool
# Bagging :  220    True
# dtype: bool
# RandomForestClassifier : 221    True
# dtype: bool
# DecisionTreeClassifier : 222    True
# dtype: bool
# MLPClassifier : 223    True
# dtype: bool
# KNeighborsClassifier : 224    True
# dtype: bool
# Bagging :  225    True
# dtype: bool
# RandomForestClassifier : 226    True
# dtype: bool
# DecisionTreeClassifier : 227    True
# dtype: bool
# MLPClassifier : 228    True
# dtype: bool
# KNeighborsClassifier : 229    True
# dtype: bool
# Bagging :  230    True
# dtype: bool
# RandomForestClassifier : 231    True
# dtype: bool
# DecisionTreeClassifier : 232    True
# dtype: bool
# MLPClassifier : 233    True
# dtype: bool
# KNeighborsClassifier : 234    True
# dtype: bool
# Bagging :  235    True
# dtype: bool
# RandomForestClassifier : 236    True
# dtype: bool
# DecisionTreeClassifier : 237    True
# dtype: bool
# MLPClassifier : 238    True
# dtype: bool
# KNeighborsClassifier : 239    True
# dtype: bool
# Bagging :  240    True
# dtype: bool
# RandomForestClassifier : 241    True
# dtype: bool
# DecisionTreeClassifier : 242    True
# dtype: bool
# MLPClassifier : 243    True
# dtype: bool
# KNeighborsClassifier : 244    True
# dtype: bool
# Bagging :  245    True
# dtype: bool
# RandomForestClassifier : 246    True
# dtype: bool
# DecisionTreeClassifier : 247    True
# dtype: bool
# MLPClassifier : 248    True
# dtype: bool
# KNeighborsClassifier : 249    True
# dtype: bool
# Bagging :  250    False
# dtype: bool
# RandomForestClassifier : 251    True
# dtype: bool
# DecisionTreeClassifier : 252    True
# dtype: bool
# MLPClassifier : 253    True
# dtype: bool
# KNeighborsClassifier : 254    True
# dtype: bool
# Bagging :  255    False
# dtype: bool
# RandomForestClassifier : 256    False
# dtype: bool
# DecisionTreeClassifier : 257    True
# dtype: bool
# MLPClassifier : 258    True
# dtype: bool
# KNeighborsClassifier : 259    True
# dtype: bool
# Bagging :  260    False
# dtype: bool
# RandomForestClassifier : 261    False
# dtype: bool
# DecisionTreeClassifier : 262    False
# dtype: bool
# MLPClassifier : 263    True
# dtype: bool
# KNeighborsClassifier : 264    True
# dtype: bool
# Bagging :  265    True
# dtype: bool
# RandomForestClassifier : 266    True
# dtype: bool
# DecisionTreeClassifier : 267    True
# dtype: bool
# MLPClassifier : 268    True
# dtype: bool
# KNeighborsClassifier : 269    True
# dtype: bool
# Bagging :  270    False
# dtype: bool
# RandomForestClassifier : 271    True
# dtype: bool
# DecisionTreeClassifier : 272    True
# dtype: bool
# MLPClassifier : 273    True
# dtype: bool
# KNeighborsClassifier : 274    True
# dtype: bool
# Bagging :  275    True
# dtype: bool
# RandomForestClassifier : 276    True
# dtype: bool
# DecisionTreeClassifier : 277    True
# dtype: bool
# MLPClassifier : 278    True
# dtype: bool
# KNeighborsClassifier : 279    True
# dtype: bool
# Bagging :  280    False
# dtype: bool
# RandomForestClassifier : 281    False
# dtype: bool
# DecisionTreeClassifier : 282    True
# dtype: bool
# MLPClassifier : 283    True
# dtype: bool
# KNeighborsClassifier : 284    True
# dtype: bool
# Bagging :  285    False
# dtype: bool
# RandomForestClassifier : 286    False
# dtype: bool
# DecisionTreeClassifier : 287    False
# dtype: bool
# MLPClassifier : 288    True
# dtype: bool
# KNeighborsClassifier : 289    True
# dtype: bool
# Bagging :  290    False
# dtype: bool
# RandomForestClassifier : 291    False
# dtype: bool
# DecisionTreeClassifier : 292    True
# dtype: bool
# MLPClassifier : 293    True
# dtype: bool
# KNeighborsClassifier : 294    True
# dtype: bool
# Bagging :  295    False
# dtype: bool
# RandomForestClassifier : 296    False
# dtype: bool
# DecisionTreeClassifier : 297    True
# dtype: bool
# MLPClassifier : 298    True
# dtype: bool
# KNeighborsClassifier : 299    False
# dtype: bool
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
# ...
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
# C:\Users\User\AppData\Local\Temp\ipykernel_21128\109805346.py:18: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   'T_Student' if bagging_is_normal.bool() and model_is_normal.bool() else 'Wilcoxon'
#      metric  ...     prueba
# 0      Exac  ...  T_Student
# 1      Exac  ...  T_Student
# 2      Exac  ...  T_Student
# 3      Exac  ...  T_Student
# 5      Exac  ...  T_Student
# ..      ...  ...        ...
# 215  AUC_PS  ...  T_Student
# 220  AUC_PS  ...  T_Student
# 221  AUC_PS  ...  T_Student
# 222  AUC_PS  ...  T_Student
# 223  AUC_PS  ...  T_Student
#
# [138 rows x 5 columns]

# %%
""" Test de Wilcoxon """
# H0 (hipótesis nula): La mediana de las diferencias es igual a 0
# H1 (hipótesis alternativa): La mediana de las diferencias es diferente de 0
# Nivel de significancia = 0.05
# Si p <= nivel de significancia  ->  Se rechaza H0 (al menos una muestra difiere de las demás)
df_shapiro_wilk = pd.DataFrame(columns=["metric", "label", "models", "stadistic", "p_value", "las muestras difieren?"])
nivel_significancia_normalidad = 0.05

df_test_diferencias_significativas = pd.DataFrame(columns=["metric", "label", "models", "stadistic", "p_value", "las muestras difieren?"])
nivel_significancia = 0.0125
list_models = ['RandomForestClassifier', 'DecisionTreeClassifier', 'MLPClassifier', 'KNeighborsClassifier']

for metric in metric_list : 
  for label in label_list :
    lista_wilcoxon = []
    for model in ['IDSBaggingClassifier']+list_models :
      muestra = df_results_ordered[
        (df_results_ordered['metric'] == metric) & 
        (df_results_ordered['label'] == label) & 
        (df_results_ordered['model'] == model)
      ][iter_list].iloc[0].to_list()
      if model == 'IDSBaggingClassifier' : 
        muestra_bagging_model = muestra
        normal_stats, normal_p = stats.shapiro(muestra_bagging_model)
        bagging_is_normal = normal_p >  
      else : 
        stat, p = stats.wilcoxon(muestra_bagging_model, muestra, alternative='greater')

        df_test_diferencias_significativas.loc[len(df_test_diferencias_significativas)] = [
          metric,
          label,
          f'IDSBaggingClassifier > {model}',
          stat,
          p,
          p <= nivel_significancia
        ]
df_test_diferencias_significativas
# Out:
#   Cell In[16], line 25
#     bagging_is_normal = normal_p >
#                                     ^
# SyntaxError: invalid syntax

# %%
df_test_wilcoxon.to_excel('output/df_wilcoxon_greater.xlsx', index=False)

# %%
with pd.ExcelWriter('output/analisis_descriptivo.xlsx', engine='openpyxl') as writer: 
  for metric in metric_list : 
    for label in label_list : 
      df_results_ordered_by_model[
        (df_results_ordered_by_model['metric'] == metric) & 
        (df_results_ordered_by_model['label'] == label) 
      ][model_list].describe().to_excel(writer, sheet_name=f'{metric}_{label}')

# %%
df_results_ordered_by_model[
  (df_results_ordered_by_model['metric'] == 'Exac') & 
  (df_results_ordered_by_model['label'] == 'BENIGN') 
][model_list].describe()
# Out:
# model  RandomForestClassifier  DecisionTreeClassifier  MLPClassifier  \
# count               10.000000               10.000000      10.000000
# mean                 0.999406                0.998576       0.988831
# std                  0.000465                0.000572       0.000885
# min                  0.998176                0.997234       0.987407
# 25%                  0.999367                0.998588       0.988598
# 50%                  0.999500                0.998764       0.988819
# 75%                  0.999632                0.998911       0.989246
# max                  0.999823                0.999058       0.990467
#
# model  KNeighborsClassifier  IDSBaggingClassifier
# count             10.000000             10.000000
# mean               0.998311              0.999500
# std                0.000266              0.000089
# min                0.997999              0.999353
# 25%                0.998073              0.999470
# 50%                0.998323              0.999529
# 75%                0.998499              0.999573
# max                0.998764              0.999588
