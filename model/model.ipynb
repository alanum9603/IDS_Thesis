# %%
# Importaciones
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import time
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, roc_auc_score, precision_recall_curve, auc
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import resample

# %%
CARACTERISTICAS_VAR_INF  = ['flow_bytes/s']

CARACTERISTICAS_VAR_NULL = ['flow_iat_min', 'flow_bytes/s']

NUM_SELECTED_CHARS = [
  'bwd_iat_min', 'packet_length_std', 'flow_bytes/s', 'cwr_flag_count', 'flow_iat_min', 
  'fwd_iat_min', 'fwd_bulk_rate_avg', 'subflow_bwd_packets', 'active_std', 
  'bwd_bytes/bulk_avg', 'flow_duration', 'fwd_packet_length_max', 'subflow_fwd_packets', 
  'down/up_ratio', 'idle_max', 'fwd_act_data_pkts', 'rst_flag_count'
]

CAT_SELECTED_CHARS = ['port_type_registered', 'port_type_well_known', 'protocol_6', 'protocol_17']

CARACTERISTICA_OBJETIVO = "label"

DB_PATH = "DB/"

# %%
# df_ = pd.read_csv("DB/1/df_train_dt.csv")

# %%
bagging_model = [
  {
    'path_name' : 'rf', 
    'model_name' : 'RandomForestClassifier',
    'model' : RandomForestClassifier(criterion="gini", class_weight='balanced', max_depth=20, n_estimators=100, bootstrap=True, random_state=9603)
  },
  {
    'path_name' : 'dt', 
    'model_name' : 'DecisionTreeClassifier',
    'model' : DecisionTreeClassifier(criterion="gini", class_weight='balanced', max_depth=20, random_state=9603)
  },
  {
    'path_name' : 'mlp',
    'model_name' : 'MLPClassifier',
    'model' : MLPClassifier(hidden_layer_sizes=(64,), max_iter=100, early_stopping=True, random_state=9603)
  },
  {
    'path_name' : 'knn',
    'model_name' : 'KNeighborsClassifier',
    'model' : KNeighborsClassifier(n_neighbors=3, weights='distance', metric='manhattan')
  },
]

# %%
# getFrequency(): Función para obtener la distribución de frecuencias de la columna label
def getFrequency(df : pd.DataFrame, caracteristica) :
  frecuencia = df[caracteristica].value_counts()
  porcentaje = df[caracteristica].value_counts(normalize=True) * 100

  tabla_frecuencia = pd.DataFrame({
    "Frecuencia": frecuencia,
    "Frecuencia(%)": porcentaje
  })
  
  tabla_frecuencia["Frecuencia(%)"].round(2)
  
  print(tabla_frecuencia)
  print(df.shape)

# %% [markdown]
# # A

# %%
def transform(df_ : pd.DataFrame) : 
  df = df_.copy()
  df['protocol_6'] = (df['protocol'] == 6).astype(int)
  df['protocol_17'] = (df['protocol'] == 17).astype(int)
  df = df[CAT_SELECTED_CHARS+NUM_SELECTED_CHARS+[CARACTERISTICA_OBJETIVO]]
  df[CARACTERISTICA_OBJETIVO] = df[CARACTERISTICA_OBJETIVO].apply(lambda x : LABELS[x])
  print(df.columns)
  getFrequency(df, CARACTERISTICA_OBJETIVO)
  return df

# %%
# df_test = pd.read_csv('DB/pre/1/df_test.csv')
# df_test = transform(df_test)

# %%
# for i in range(10) : 
#   for j in bagging_model : 
#     print("Transformación de conjunto de validación")
#     df_valid = pd.read_csv(f"DB/pre/{i+1}/df_valid_{j['path_name']}.csv")
#     df_valid = transform(df_valid)
#     df_valid.to_csv(f"DB/{i+1}/df_valid_{j['path_name']}.csv")
#   df_test = pd.read_csv(f"DB/pre/{i+1}/df_test.csv")
#   df_test = transform(df_test)
#   df_test.to_csv(f"DB/{i+1}/df_test.csv")

# %% [markdown]
# # B

# %%
df_ = pd.read_csv('DB/1/df_train_rf.csv')
LABELS = sorted(df_['label'].unique())
LABELS
# Out:
# ['BENIGN',
#  'BOT',
#  'DDOS',
#  'DOS_GOLDENEYE',
#  'DOS_HULK',
#  'DOS_SLOWHTTPTEST',
#  'DOS_SLOWLORIS',
#  'FTP_PATATOR',
#  'PORTSCAN',
#  'SSH_PATATOR']

# %%
encoder = LabelEncoder()

# %%
# get_results() : Función para automatizar la generación de la Matriz de confusión y AUC de las curvas ROC y Sensibilidad Precisión
def get_results(y_test, y_pred, threshold) :
  y_pred_under_threshold = y_pred >= threshold
  y_pred_for_cm = y_pred_under_threshold.astype(int)
  """
  Matriz de confusión
              Predicted
              0     1
  Actual 0  [[TN,   FP],
         1   [FN,   TP]]
  """
  cm = confusion_matrix(y_test, y_pred_for_cm)
  auc_roc = roc_auc_score(y_test, y_pred)
  precision, recall, pr_thresholds = precision_recall_curve(y_test, y_pred)
  auc_sp = auc(recall, precision)
  
  return cm, auc_roc, auc_sp

# %%
# one_hot_encode() : Función para codificar la variable objetivo en razón de las clases que codificó la instancia de Machine Learning
def one_hot_encode(y, classes) : 
  one_hot = np.zeros((len(y), len(classes)))
  for i, label in enumerate(y) :
    one_hot[i, int(label)] = 1
  return one_hot

# %%
def save_df(X_, y_, save_path) : 
  df_save = pd.DataFrame(X_, columns=CAT_SELECTED_CHARS+NUM_SELECTED_CHARS)
  df_save[CARACTERISTICA_OBJETIVO] = y_

  df_save.to_csv(save_path, index=False)

# %%
df_validation = pd.DataFrame(columns=["iter", "model", "label", "TP", "TN", "FP", "FN", "AUC_SP", "ms"])
df_testing    = pd.DataFrame(columns=["iter", "model", "label", "TP", "TN", "FP", "FN", "Exac", "Prec", "Sens", "F1", "AUC_SP", "ms"])

for iter in range(10) : 
  print(f"""
    Iteración {iter+1}
  """)
  results_list = []
  for instance in bagging_model : 
    print("Modelo", instance['model_name'])
    df_train = pd.read_csv(f"{DB_PATH}{iter+1}/df_train_{instance['path_name']}.csv")
    X_train = df_train.drop([CARACTERISTICA_OBJETIVO], axis=1).values
    y_train = encoder.fit_transform(df_train[CARACTERISTICA_OBJETIVO].values.ravel())

    df_valid = pd.read_csv(f"{DB_PATH}{iter+1}/df_valid_{instance['path_name']}.csv")
    X_valid = df_valid.drop([CARACTERISTICA_OBJETIVO], axis=1).values
    y_valid = one_hot_encode(
      encoder.transform(df_valid[CARACTERISTICA_OBJETIVO].values.ravel()), 
      LABELS
    )
    print("Conjunto de entrenamiento")
    getFrequency(df_train, 'label')
    print("Conjunto de validación")
    getFrequency(df_valid, 'label')

    print("Entrenamiento")

    instance['model'].fit(X_train, y_train)

    print("Validación")

    valid_start = time.time()
    y_valid_pred = instance['model'].predict_proba(X_valid)
    valid_end = time.time()

    for i in range(len(LABELS)) : 
      cm, auc_roc, auc_sp = get_results(
        y_test=y_valid[:,i],
        y_pred=y_valid_pred[:,i],
        threshold=0.5
      )
      df_validation.loc[len(df_validation)] = [
        f"Iteración {iter+1}",
        instance["model_name"], 
        LABELS[i],
        cm[1][1], 
        cm[0][0], 
        cm[0][1], 
        cm[1][0], 
        auc_sp, 
        valid_end-valid_start
      ]

    print("Prueba del modelo")
    X_test = pd.read_csv(f"{DB_PATH}{iter+1}/df_test_{instance['path_name']}.csv").drop([CARACTERISTICA_OBJETIVO], axis=1).values

    """ Prueba de los modelos """
    pred_start = time.perf_counter()
    y_pred = instance["model"].predict_proba(X_test)
    pred_end   = time.perf_counter()

    print("Registro de resultados")
    results_list.append({
      "model" : instance["model_name"],
      "pred" : y_pred,
      "time_start" : pred_start,
      "time_end" : pred_end
    })

  y_test = pd.read_csv(f"{DB_PATH}{iter+1}/df_test_rf.csv")[CARACTERISTICA_OBJETIVO]
  y_test = one_hot_encode(
    encoder.transform(y_test.values.ravel()), 
    LABELS
  )

  print(f'results_list : {len(results_list)}')
  y_pred_bagging = np.zeros(y_test.shape)
  print(f"y_pred_bagging : {y_pred_bagging.shape}")

  for result in results_list : 
    print(f"y_pred_{result['model']} : {result['pred'].shape}")
    y_pred_bagging = y_pred_bagging + result['pred']

  y_pred_bagging /= 4

  results_list.append({
    'model' : 'BaggingClassifier',
    'pred' : y_pred_bagging,
    'time_start' : results_list[0]["time_start"],
    "time_end" : results_list[3]["time_end"]
  })
  print(f'results_list : {len(results_list)}')

  for result in results_list : 
    for i in range(len(LABELS)) :
      cm, auc_roc, auc_sp = get_results(
        y_test=y_test[:,i],
        y_pred=result["pred"][:,i],
        threshold=0.5
      )
      exac = (cm[1][1] + cm[0][0])/(cm[1][1]+cm[0][0]+cm[0][1]+cm[1][0])
      prec = (cm[1][1])/(cm[1][1]+cm[0][1])
      sens = (cm[1][1])/(cm[1][1]+cm[1][0])
      F1sc = (sens*prec*2)/(sens+prec)
      df_testing.loc[len(df_testing)] = [
        f"Iteración {iter+1}",
        result["model"],
        LABELS[i],
        cm[1][1], 
        cm[0][0], 
        cm[0][1], 
        cm[1][0], 
        exac,
        prec,
        sens,
        F1sc,
        auc_sp, 
        result["time_end"] - result["time_start"]
      ]
  iter+=1
      
# pd.DataFrame(columns=["iter", "model", "label", "TP", "TN", "FP", "FN", "Exac", "Prec", "Sens", "F1", "AUC_SP", "ms"])
# Out:
#     Iteración 1
#
# Modelo RandomForestClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77779      47.046406
# PORTSCAN               13428       8.122233
# DOS_HULK               13371       8.087755
# DDOS                    8678       5.249087
# SSH_PATATOR             8678       5.249087
# DOS_SLOWLORIS           8678       5.249087
# DOS_SLOWHTTPTEST        8678       5.249087
# DOS_GOLDENEYE           8678       5.249087
# FTP_PATATOR             8678       5.249087
# BOT                     8678       5.249087
# (165324, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49148      68.054113
# PORTSCAN                8467      11.724062
# DOS_HULK                8425      11.665905
# DDOS                    5042       6.981542
# DOS_GOLDENEYE            416       0.576026
# FTP_PATATOR              224       0.310168
# DOS_SLOWLORIS            208       0.288013
# SSH_PATATOR              156       0.216010
# DOS_SLOWHTTPTEST          94       0.130160
# BOT                       39       0.054002
# (72219, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo DecisionTreeClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77830      47.062736
# PORTSCAN               13428       8.119728
# DOS_HULK               13371       8.085261
# DDOS                    8678       5.247468
# DOS_SLOWLORIS           8678       5.247468
# DOS_GOLDENEYE           8678       5.247468
# DOS_SLOWHTTPTEST        8678       5.247468
# FTP_PATATOR             8678       5.247468
# SSH_PATATOR             8678       5.247468
# BOT                     8678       5.247468
# (165375, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49078      68.119422
# PORTSCAN                8438      11.711799
# DOS_HULK                8363      11.607701
# DDOS                    5063       7.027357
# DOS_GOLDENEYE            396       0.549641
# DOS_SLOWLORIS            223       0.309520
# FTP_PATATOR              207       0.287312
# SSH_PATATOR              152       0.210973
# DOS_SLOWHTTPTEST          89       0.123530
# BOT                       38       0.052743
# (72047, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo MLPClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77793      47.050890
# PORTSCAN               13428       8.121545
# DOS_HULK               13371       8.087070
# DDOS                    8678       5.248642
# DOS_GOLDENEYE           8678       5.248642
# DOS_SLOWLORIS           8678       5.248642
# BOT                     8678       5.248642
# DOS_SLOWHTTPTEST        8678       5.248642
# SSH_PATATOR             8678       5.248642
# FTP_PATATOR             8678       5.248642
# (165338, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49173      68.011507
# PORTSCAN                8468      11.712148
# DOS_HULK                8446      11.681719
# DDOS                    5084       7.031715
# DOS_GOLDENEYE            403       0.557392
# DOS_SLOWLORIS            220       0.304283
# FTP_PATATOR              215       0.297368
# SSH_PATATOR              160       0.221297
# DOS_SLOWHTTPTEST          92       0.127246
# BOT                       40       0.055324
# (72301, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo KNeighborsClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77782      47.047367
# PORTSCAN               13428       8.122085
# DOS_HULK               13371       8.087608
# DDOS                    8678       5.248991
# DOS_GOLDENEYE           8678       5.248991
# DOS_SLOWLORIS           8678       5.248991
# FTP_PATATOR             8678       5.248991
# SSH_PATATOR             8678       5.248991
# BOT                     8678       5.248991
# DOS_SLOWHTTPTEST        8678       5.248991
# (165327, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49138      67.991310
# PORTSCAN                8479      11.732230
# DOS_HULK                8438      11.675499
# DDOS                    5096       7.051238
# DOS_GOLDENEYE            398       0.550705
# FTP_PATATOR              220       0.304410
# DOS_SLOWLORIS            210       0.290573
# SSH_PATATOR              163       0.225540
# DOS_SLOWHTTPTEST          95       0.131450
# BOT                       34       0.047045
# (72271, 22)
# Entrenamiento
# Validación
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] El sistema no puede encontrar el archivo especificado
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\User\anaconda3\envs\ids_thesis\Lib\subprocess.py", line 550, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\User\anaconda3\envs\ids_thesis\Lib\subprocess.py", line 1028, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\User\anaconda3\envs\ids_thesis\Lib\subprocess.py", line 1540, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Prueba del metamodelo Bagging
# Registro de resultados
# results_list : 4
# y_pred_bagging : (16993, 10)
# y_pred_RandomForestClassifier : (16993, 10)
# y_pred_DecisionTreeClassifier : (16993, 10)
# y_pred_MLPClassifier : (16993, 10)
# y_pred_KNeighborsClassifier : (16993, 10)
# results_list : 5
#
#     Iteración 2
#
# Modelo RandomForestClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77789      47.049609
# PORTSCAN               13428       8.121741
# DOS_HULK               13371       8.087266
# DDOS                    8678       5.248769
# SSH_PATATOR             8678       5.248769
# DOS_SLOWLORIS           8678       5.248769
# DOS_SLOWHTTPTEST        8678       5.248769
# DOS_GOLDENEYE           8678       5.248769
# FTP_PATATOR             8678       5.248769
# BOT                     8678       5.248769
# (165334, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49148      68.054113
# PORTSCAN                8467      11.724062
# DOS_HULK                8425      11.665905
# DDOS                    5042       6.981542
# DOS_GOLDENEYE            416       0.576026
# FTP_PATATOR              224       0.310168
# DOS_SLOWLORIS            208       0.288013
# SSH_PATATOR              156       0.216010
# DOS_SLOWHTTPTEST          94       0.130160
# BOT                       39       0.054002
# (72219, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo DecisionTreeClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77772      47.044164
# PORTSCAN               13428       8.122577
# DOS_HULK               13371       8.088097
# DDOS                    8678       5.249309
# DOS_SLOWLORIS           8678       5.249309
# DOS_GOLDENEYE           8678       5.249309
# DOS_SLOWHTTPTEST        8678       5.249309
# FTP_PATATOR             8678       5.249309
# SSH_PATATOR             8678       5.249309
# BOT                     8678       5.249309
# (165317, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49078      68.119422
# PORTSCAN                8438      11.711799
# DOS_HULK                8363      11.607701
# DDOS                    5063       7.027357
# DOS_GOLDENEYE            396       0.549641
# DOS_SLOWLORIS            223       0.309520
# FTP_PATATOR              207       0.287312
# SSH_PATATOR              152       0.210973
# DOS_SLOWHTTPTEST          89       0.123530
# BOT                       38       0.052743
# (72047, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo MLPClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77758      47.039679
# PORTSCAN               13428       8.123265
# DOS_HULK               13371       8.088782
# DDOS                    8678       5.249753
# DOS_GOLDENEYE           8678       5.249753
# DOS_SLOWLORIS           8678       5.249753
# BOT                     8678       5.249753
# DOS_SLOWHTTPTEST        8678       5.249753
# SSH_PATATOR             8678       5.249753
# FTP_PATATOR             8678       5.249753
# (165303, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49173      68.011507
# PORTSCAN                8468      11.712148
# DOS_HULK                8446      11.681719
# DDOS                    5084       7.031715
# DOS_GOLDENEYE            403       0.557392
# DOS_SLOWLORIS            220       0.304283
# FTP_PATATOR              215       0.297368
# SSH_PATATOR              160       0.221297
# DOS_SLOWHTTPTEST          92       0.127246
# BOT                       40       0.055324
# (72301, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo KNeighborsClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77773      47.044484
# PORTSCAN               13428       8.122527
# DOS_HULK               13371       8.088048
# DDOS                    8678       5.249277
# DOS_GOLDENEYE           8678       5.249277
# DOS_SLOWLORIS           8678       5.249277
# FTP_PATATOR             8678       5.249277
# SSH_PATATOR             8678       5.249277
# BOT                     8678       5.249277
# DOS_SLOWHTTPTEST        8678       5.249277
# (165318, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49138      67.991310
# PORTSCAN                8479      11.732230
# DOS_HULK                8438      11.675499
# DDOS                    5096       7.051238
# DOS_GOLDENEYE            398       0.550705
# FTP_PATATOR              220       0.304410
# DOS_SLOWLORIS            210       0.290573
# SSH_PATATOR              163       0.225540
# DOS_SLOWHTTPTEST          95       0.131450
# BOT                       34       0.047045
# (72271, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# results_list : 4
# y_pred_bagging : (16993, 10)
# y_pred_RandomForestClassifier : (16993, 10)
# y_pred_DecisionTreeClassifier : (16993, 10)
# y_pred_MLPClassifier : (16993, 10)
# y_pred_KNeighborsClassifier : (16993, 10)
# results_list : 5
#
#     Iteración 3
#
# Modelo RandomForestClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77781      47.047046
# PORTSCAN               13428       8.122134
# DOS_HULK               13371       8.087657
# DDOS                    8678       5.249023
# SSH_PATATOR             8678       5.249023
# DOS_SLOWLORIS           8678       5.249023
# DOS_SLOWHTTPTEST        8678       5.249023
# DOS_GOLDENEYE           8678       5.249023
# FTP_PATATOR             8678       5.249023
# BOT                     8678       5.249023
# (165326, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49148      68.054113
# PORTSCAN                8467      11.724062
# DOS_HULK                8425      11.665905
# DDOS                    5042       6.981542
# DOS_GOLDENEYE            416       0.576026
# FTP_PATATOR              224       0.310168
# DOS_SLOWLORIS            208       0.288013
# SSH_PATATOR              156       0.216010
# DOS_SLOWHTTPTEST          94       0.130160
# BOT                       39       0.054002
# (72219, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo DecisionTreeClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77799      47.052811
# PORTSCAN               13428       8.121250
# DOS_HULK               13371       8.086777
# DDOS                    8678       5.248452
# DOS_SLOWLORIS           8678       5.248452
# DOS_GOLDENEYE           8678       5.248452
# DOS_SLOWHTTPTEST        8678       5.248452
# FTP_PATATOR             8678       5.248452
# SSH_PATATOR             8678       5.248452
# BOT                     8678       5.248452
# (165344, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49078      68.119422
# PORTSCAN                8438      11.711799
# DOS_HULK                8363      11.607701
# DDOS                    5063       7.027357
# DOS_GOLDENEYE            396       0.549641
# DOS_SLOWLORIS            223       0.309520
# FTP_PATATOR              207       0.287312
# SSH_PATATOR              152       0.210973
# DOS_SLOWHTTPTEST          89       0.123530
# BOT                       38       0.052743
# (72047, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo MLPClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77759      47.039999
# PORTSCAN               13428       8.123215
# DOS_HULK               13371       8.088733
# DDOS                    8678       5.249722
# DOS_GOLDENEYE           8678       5.249722
# DOS_SLOWLORIS           8678       5.249722
# BOT                     8678       5.249722
# DOS_SLOWHTTPTEST        8678       5.249722
# SSH_PATATOR             8678       5.249722
# FTP_PATATOR             8678       5.249722
# (165304, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49173      68.011507
# PORTSCAN                8468      11.712148
# DOS_HULK                8446      11.681719
# DDOS                    5084       7.031715
# DOS_GOLDENEYE            403       0.557392
# DOS_SLOWLORIS            220       0.304283
# FTP_PATATOR              215       0.297368
# SSH_PATATOR              160       0.221297
# DOS_SLOWHTTPTEST          92       0.127246
# BOT                       40       0.055324
# (72301, 22)
# Entrenamiento
# c:\Users\User\anaconda3\envs\ids_thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo KNeighborsClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77787      47.048968
# PORTSCAN               13428       8.121840
# DOS_HULK               13371       8.087364
# DDOS                    8678       5.248833
# DOS_GOLDENEYE           8678       5.248833
# DOS_SLOWLORIS           8678       5.248833
# FTP_PATATOR             8678       5.248833
# SSH_PATATOR             8678       5.248833
# BOT                     8678       5.248833
# DOS_SLOWHTTPTEST        8678       5.248833
# (165332, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49138      67.991310
# PORTSCAN                8479      11.732230
# DOS_HULK                8438      11.675499
# DDOS                    5096       7.051238
# DOS_GOLDENEYE            398       0.550705
# FTP_PATATOR              220       0.304410
# DOS_SLOWLORIS            210       0.290573
# SSH_PATATOR              163       0.225540
# DOS_SLOWHTTPTEST          95       0.131450
# BOT                       34       0.047045
# (72271, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# results_list : 4
# y_pred_bagging : (16993, 10)
# y_pred_RandomForestClassifier : (16993, 10)
# y_pred_DecisionTreeClassifier : (16993, 10)
# y_pred_MLPClassifier : (16993, 10)
# y_pred_KNeighborsClassifier : (16993, 10)
# results_list : 5
#
#     Iteración 4
#
# Modelo RandomForestClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77776      47.045160
# PORTSCAN               13429       8.122936
# DOS_HULK               13371       8.087853
# DDOS                    8678       5.249150
# SSH_PATATOR             8678       5.249150
# DOS_SLOWLORIS           8678       5.249150
# DOS_SLOWHTTPTEST        8678       5.249150
# DOS_GOLDENEYE           8678       5.249150
# FTP_PATATOR             8678       5.249150
# BOT                     8678       5.249150
# (165322, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49148      68.055056
# PORTSCAN                8467      11.724224
# DOS_HULK                8425      11.666067
# DDOS                    5042       6.981639
# DOS_GOLDENEYE            415       0.574649
# FTP_PATATOR              224       0.310172
# DOS_SLOWLORIS            208       0.288017
# SSH_PATATOR              156       0.216013
# DOS_SLOWHTTPTEST          94       0.130161
# BOT                       39       0.054003
# (72218, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo DecisionTreeClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77797      47.051886
# PORTSCAN               13429       8.121904
# DOS_HULK               13371       8.086826
# DDOS                    8678       5.248483
# DOS_SLOWLORIS           8678       5.248483
# DOS_GOLDENEYE           8678       5.248483
# DOS_SLOWHTTPTEST        8678       5.248483
# FTP_PATATOR             8678       5.248483
# SSH_PATATOR             8678       5.248483
# BOT                     8678       5.248483
# (165343, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49078      68.119422
# PORTSCAN                8438      11.711799
# DOS_HULK                8363      11.607701
# DDOS                    5063       7.027357
# DOS_GOLDENEYE            396       0.549641
# DOS_SLOWLORIS            223       0.309520
# FTP_PATATOR              207       0.287312
# SSH_PATATOR              152       0.210973
# DOS_SLOWHTTPTEST          89       0.123530
# BOT                       38       0.052743
# (72047, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo MLPClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77753      47.037792
# PORTSCAN               13429       8.124066
# DOS_HULK               13371       8.088978
# DDOS                    8678       5.249881
# FTP_PATATOR             8678       5.249881
# DOS_SLOWLORIS           8678       5.249881
# DOS_GOLDENEYE           8678       5.249881
# DOS_SLOWHTTPTEST        8678       5.249881
# BOT                     8678       5.249881
# SSH_PATATOR             8678       5.249881
# (165299, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49173      68.010567
# PORTSCAN                8469      11.713369
# DOS_HULK                8446      11.681558
# DDOS                    5084       7.031617
# DOS_GOLDENEYE            403       0.557384
# DOS_SLOWLORIS            220       0.304279
# FTP_PATATOR              215       0.297364
# SSH_PATATOR              160       0.221294
# DOS_SLOWHTTPTEST          92       0.127244
# BOT                       40       0.055324
# (72302, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo KNeighborsClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77790      47.049644
# PORTSCAN               13429       8.122248
# DOS_HULK               13371       8.087168
# DDOS                    8678       5.248706
# DOS_GOLDENEYE           8678       5.248706
# DOS_SLOWLORIS           8678       5.248706
# SSH_PATATOR             8678       5.248706
# FTP_PATATOR             8678       5.248706
# DOS_SLOWHTTPTEST        8678       5.248706
# BOT                     8678       5.248706
# (165336, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49138      67.996015
# PORTSCAN                8478      11.731658
# DOS_HULK                8439      11.677691
# DDOS                    5096       7.051726
# DOS_GOLDENEYE            397       0.549359
# FTP_PATATOR              219       0.303047
# DOS_SLOWLORIS            210       0.290593
# SSH_PATATOR              160       0.221404
# DOS_SLOWHTTPTEST          95       0.131459
# BOT                       34       0.047048
# (72266, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# results_list : 4
# y_pred_bagging : (16993, 10)
# y_pred_RandomForestClassifier : (16993, 10)
# y_pred_DecisionTreeClassifier : (16993, 10)
# y_pred_MLPClassifier : (16993, 10)
# y_pred_KNeighborsClassifier : (16993, 10)
# results_list : 5
#
#     Iteración 5
#
# Modelo RandomForestClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77777      47.045481
# PORTSCAN               13429       8.122887
# DOS_HULK               13371       8.087804
# DDOS                    8678       5.249118
# SSH_PATATOR             8678       5.249118
# DOS_SLOWLORIS           8678       5.249118
# DOS_SLOWHTTPTEST        8678       5.249118
# DOS_GOLDENEYE           8678       5.249118
# FTP_PATATOR             8678       5.249118
# BOT                     8678       5.249118
# (165323, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49148      68.055056
# PORTSCAN                8467      11.724224
# DOS_HULK                8425      11.666067
# DDOS                    5042       6.981639
# DOS_GOLDENEYE            415       0.574649
# FTP_PATATOR              224       0.310172
# DOS_SLOWLORIS            208       0.288017
# SSH_PATATOR              156       0.216013
# DOS_SLOWHTTPTEST          94       0.130161
# BOT                       39       0.054003
# (72218, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo DecisionTreeClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77753      47.037792
# PORTSCAN               13429       8.124066
# DOS_HULK               13371       8.088978
# DDOS                    8678       5.249881
# DOS_SLOWLORIS           8678       5.249881
# DOS_GOLDENEYE           8678       5.249881
# DOS_SLOWHTTPTEST        8678       5.249881
# FTP_PATATOR             8678       5.249881
# SSH_PATATOR             8678       5.249881
# BOT                     8678       5.249881
# (165299, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49078      68.119422
# PORTSCAN                8438      11.711799
# DOS_HULK                8363      11.607701
# DDOS                    5063       7.027357
# DOS_GOLDENEYE            396       0.549641
# DOS_SLOWLORIS            223       0.309520
# FTP_PATATOR              207       0.287312
# SSH_PATATOR              152       0.210973
# DOS_SLOWHTTPTEST          89       0.123530
# BOT                       38       0.052743
# (72047, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo MLPClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77783      47.047402
# PORTSCAN               13429       8.122592
# DOS_HULK               13371       8.087510
# DDOS                    8678       5.248928
# FTP_PATATOR             8678       5.248928
# DOS_SLOWLORIS           8678       5.248928
# DOS_GOLDENEYE           8678       5.248928
# DOS_SLOWHTTPTEST        8678       5.248928
# BOT                     8678       5.248928
# SSH_PATATOR             8678       5.248928
# (165329, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49173      68.010567
# PORTSCAN                8469      11.713369
# DOS_HULK                8446      11.681558
# DDOS                    5084       7.031617
# DOS_GOLDENEYE            403       0.557384
# DOS_SLOWLORIS            220       0.304279
# FTP_PATATOR              215       0.297364
# SSH_PATATOR              160       0.221294
# DOS_SLOWHTTPTEST          92       0.127244
# BOT                       40       0.055324
# (72302, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo KNeighborsClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77757      47.039074
# PORTSCAN               13429       8.123870
# DOS_HULK               13371       8.088782
# DDOS                    8678       5.249753
# DOS_GOLDENEYE           8678       5.249753
# DOS_SLOWLORIS           8678       5.249753
# SSH_PATATOR             8678       5.249753
# FTP_PATATOR             8678       5.249753
# DOS_SLOWHTTPTEST        8678       5.249753
# BOT                     8678       5.249753
# (165303, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49138      67.996015
# PORTSCAN                8478      11.731658
# DOS_HULK                8439      11.677691
# DDOS                    5096       7.051726
# DOS_GOLDENEYE            397       0.549359
# FTP_PATATOR              219       0.303047
# DOS_SLOWLORIS            210       0.290593
# SSH_PATATOR              160       0.221404
# DOS_SLOWHTTPTEST          95       0.131459
# BOT                       34       0.047048
# (72266, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# results_list : 4
# y_pred_bagging : (16993, 10)
# y_pred_RandomForestClassifier : (16993, 10)
# y_pred_DecisionTreeClassifier : (16993, 10)
# y_pred_MLPClassifier : (16993, 10)
# y_pred_KNeighborsClassifier : (16993, 10)
# results_list : 5
#
#     Iteración 6
#
# Modelo RandomForestClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77796      47.051566
# PORTSCAN               13429       8.121953
# DOS_HULK               13371       8.086874
# DDOS                    8678       5.248515
# SSH_PATATOR             8678       5.248515
# DOS_SLOWLORIS           8678       5.248515
# DOS_SLOWHTTPTEST        8678       5.248515
# DOS_GOLDENEYE           8678       5.248515
# FTP_PATATOR             8678       5.248515
# BOT                     8678       5.248515
# (165342, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49148      68.055056
# PORTSCAN                8467      11.724224
# DOS_HULK                8425      11.666067
# DDOS                    5042       6.981639
# DOS_GOLDENEYE            415       0.574649
# FTP_PATATOR              224       0.310172
# DOS_SLOWLORIS            208       0.288017
# SSH_PATATOR              156       0.216013
# DOS_SLOWHTTPTEST          94       0.130161
# BOT                       39       0.054003
# (72218, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo DecisionTreeClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77804      47.054128
# PORTSCAN               13429       8.121560
# DOS_HULK               13371       8.086483
# DDOS                    8678       5.248261
# DOS_SLOWLORIS           8678       5.248261
# DOS_GOLDENEYE           8678       5.248261
# DOS_SLOWHTTPTEST        8678       5.248261
# FTP_PATATOR             8678       5.248261
# SSH_PATATOR             8678       5.248261
# BOT                     8678       5.248261
# (165350, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49078      68.119422
# PORTSCAN                8438      11.711799
# DOS_HULK                8363      11.607701
# DDOS                    5063       7.027357
# DOS_GOLDENEYE            396       0.549641
# DOS_SLOWLORIS            223       0.309520
# FTP_PATATOR              207       0.287312
# SSH_PATATOR              152       0.210973
# DOS_SLOWHTTPTEST          89       0.123530
# BOT                       38       0.052743
# (72047, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo MLPClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77810      47.056049
# PORTSCAN               13429       8.121266
# DOS_HULK               13371       8.086190
# DDOS                    8678       5.248071
# FTP_PATATOR             8678       5.248071
# DOS_SLOWLORIS           8678       5.248071
# DOS_GOLDENEYE           8678       5.248071
# DOS_SLOWHTTPTEST        8678       5.248071
# BOT                     8678       5.248071
# SSH_PATATOR             8678       5.248071
# (165356, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49173      68.010567
# PORTSCAN                8469      11.713369
# DOS_HULK                8446      11.681558
# DDOS                    5084       7.031617
# DOS_GOLDENEYE            403       0.557384
# DOS_SLOWLORIS            220       0.304279
# FTP_PATATOR              215       0.297364
# SSH_PATATOR              160       0.221294
# DOS_SLOWHTTPTEST          92       0.127244
# BOT                       40       0.055324
# (72302, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo KNeighborsClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77789      47.049324
# PORTSCAN               13429       8.122297
# DOS_HULK               13371       8.087217
# DDOS                    8678       5.248737
# DOS_GOLDENEYE           8678       5.248737
# DOS_SLOWLORIS           8678       5.248737
# SSH_PATATOR             8678       5.248737
# FTP_PATATOR             8678       5.248737
# DOS_SLOWHTTPTEST        8678       5.248737
# BOT                     8678       5.248737
# (165335, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49138      67.996015
# PORTSCAN                8478      11.731658
# DOS_HULK                8439      11.677691
# DDOS                    5096       7.051726
# DOS_GOLDENEYE            397       0.549359
# FTP_PATATOR              219       0.303047
# DOS_SLOWLORIS            210       0.290593
# SSH_PATATOR              160       0.221404
# DOS_SLOWHTTPTEST          95       0.131459
# BOT                       34       0.047048
# (72266, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# results_list : 4
# y_pred_bagging : (16993, 10)
# y_pred_RandomForestClassifier : (16993, 10)
# y_pred_DecisionTreeClassifier : (16993, 10)
# y_pred_MLPClassifier : (16993, 10)
# y_pred_KNeighborsClassifier : (16993, 10)
# results_list : 5
#
#     Iteración 7
#
# Modelo RandomForestClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77806      47.054768
# PORTSCAN               13429       8.121462
# DOS_HULK               13371       8.086385
# DDOS                    8678       5.248198
# DOS_GOLDENEYE           8678       5.248198
# DOS_SLOWLORIS           8678       5.248198
# FTP_PATATOR             8678       5.248198
# SSH_PATATOR             8678       5.248198
# DOS_SLOWHTTPTEST        8678       5.248198
# BOT                     8678       5.248198
# (165352, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49148      68.055998
# PORTSCAN                8466      11.723002
# DOS_HULK                8425      11.666228
# DDOS                    5042       6.981736
# DOS_GOLDENEYE            415       0.574657
# FTP_PATATOR              225       0.311561
# DOS_SLOWLORIS            208       0.288021
# SSH_PATATOR              155       0.214631
# DOS_SLOWHTTPTEST          95       0.131548
# BOT                       38       0.052619
# (72217, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo DecisionTreeClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77794      47.050925
# PORTSCAN               13429       8.122052
# DOS_HULK               13371       8.086972
# DDOS                    8678       5.248579
# DOS_SLOWLORIS           8678       5.248579
# DOS_GOLDENEYE           8678       5.248579
# DOS_SLOWHTTPTEST        8678       5.248579
# FTP_PATATOR             8678       5.248579
# SSH_PATATOR             8678       5.248579
# BOT                     8678       5.248579
# (165340, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49078      68.120368
# PORTSCAN                8438      11.711962
# DOS_HULK                8362      11.606474
# DDOS                    5063       7.027455
# DOS_GOLDENEYE            396       0.549649
# DOS_SLOWLORIS            223       0.309524
# FTP_PATATOR              207       0.287316
# SSH_PATATOR              152       0.210976
# DOS_SLOWHTTPTEST          90       0.124920
# BOT                       37       0.051356
# (72046, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo MLPClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77792      47.050285
# PORTSCAN               13429       8.122150
# DOS_HULK               13371       8.087070
# DDOS                    8678       5.248642
# FTP_PATATOR             8678       5.248642
# DOS_SLOWHTTPTEST        8678       5.248642
# DOS_GOLDENEYE           8678       5.248642
# DOS_SLOWLORIS           8678       5.248642
# SSH_PATATOR             8678       5.248642
# BOT                     8678       5.248642
# (165338, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49173      68.011507
# PORTSCAN                8469      11.713531
# DOS_HULK                8446      11.681719
# DDOS                    5084       7.031715
# DOS_GOLDENEYE            403       0.557392
# DOS_SLOWLORIS            220       0.304283
# FTP_PATATOR              215       0.297368
# SSH_PATATOR              160       0.221297
# DOS_SLOWHTTPTEST          92       0.127246
# BOT                       39       0.053941
# (72301, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo KNeighborsClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77836      47.064372
# PORTSCAN               13429       8.119989
# DOS_HULK               13371       8.084919
# DDOS                    8678       5.247246
# SSH_PATATOR             8678       5.247246
# FTP_PATATOR             8678       5.247246
# DOS_GOLDENEYE           8678       5.247246
# DOS_SLOWLORIS           8678       5.247246
# DOS_SLOWHTTPTEST        8678       5.247246
# BOT                     8678       5.247246
# (165382, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49138      67.991310
# PORTSCAN                8479      11.732230
# DOS_HULK                8438      11.675499
# DDOS                    5094       7.048470
# DOS_GOLDENEYE            399       0.552089
# FTP_PATATOR              224       0.309945
# DOS_SLOWLORIS            208       0.287806
# SSH_PATATOR              161       0.222773
# DOS_SLOWHTTPTEST          97       0.134217
# BOT                       33       0.045661
# (72271, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# results_list : 4
# y_pred_bagging : (16993, 10)
# y_pred_RandomForestClassifier : (16993, 10)
# y_pred_DecisionTreeClassifier : (16993, 10)
# y_pred_MLPClassifier : (16993, 10)
# y_pred_KNeighborsClassifier : (16993, 10)
# results_list : 5
#
#     Iteración 8
#
# Modelo RandomForestClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77829      47.062132
# PORTSCAN               13429       8.120333
# DOS_HULK               13371       8.085261
# DDOS                    8678       5.247468
# DOS_GOLDENEYE           8678       5.247468
# DOS_SLOWLORIS           8678       5.247468
# FTP_PATATOR             8678       5.247468
# SSH_PATATOR             8678       5.247468
# DOS_SLOWHTTPTEST        8678       5.247468
# BOT                     8678       5.247468
# (165375, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49148      68.055998
# PORTSCAN                8466      11.723002
# DOS_HULK                8425      11.666228
# DDOS                    5042       6.981736
# DOS_GOLDENEYE            415       0.574657
# FTP_PATATOR              225       0.311561
# DOS_SLOWLORIS            208       0.288021
# SSH_PATATOR              155       0.214631
# DOS_SLOWHTTPTEST          95       0.131548
# BOT                       38       0.052619
# (72217, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo DecisionTreeClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77813      47.057009
# PORTSCAN               13429       8.121118
# DOS_HULK               13371       8.086043
# DDOS                    8678       5.247976
# DOS_SLOWLORIS           8678       5.247976
# DOS_GOLDENEYE           8678       5.247976
# DOS_SLOWHTTPTEST        8678       5.247976
# FTP_PATATOR             8678       5.247976
# SSH_PATATOR             8678       5.247976
# BOT                     8678       5.247976
# (165359, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49078      68.120368
# PORTSCAN                8438      11.711962
# DOS_HULK                8362      11.606474
# DDOS                    5063       7.027455
# DOS_GOLDENEYE            396       0.549649
# DOS_SLOWLORIS            223       0.309524
# FTP_PATATOR              207       0.287316
# SSH_PATATOR              152       0.210976
# DOS_SLOWHTTPTEST          90       0.124920
# BOT                       37       0.051356
# (72046, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo MLPClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77813      47.057009
# PORTSCAN               13429       8.121118
# DOS_HULK               13371       8.086043
# DDOS                    8678       5.247976
# FTP_PATATOR             8678       5.247976
# DOS_SLOWHTTPTEST        8678       5.247976
# DOS_GOLDENEYE           8678       5.247976
# DOS_SLOWLORIS           8678       5.247976
# SSH_PATATOR             8678       5.247976
# BOT                     8678       5.247976
# (165359, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49173      68.011507
# PORTSCAN                8469      11.713531
# DOS_HULK                8446      11.681719
# DDOS                    5084       7.031715
# DOS_GOLDENEYE            403       0.557392
# DOS_SLOWLORIS            220       0.304283
# FTP_PATATOR              215       0.297368
# SSH_PATATOR              160       0.221297
# DOS_SLOWHTTPTEST          92       0.127246
# BOT                       39       0.053941
# (72301, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo KNeighborsClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77754      47.038113
# PORTSCAN               13429       8.124017
# DOS_HULK               13371       8.088929
# DDOS                    8678       5.249849
# SSH_PATATOR             8678       5.249849
# FTP_PATATOR             8678       5.249849
# DOS_GOLDENEYE           8678       5.249849
# DOS_SLOWLORIS           8678       5.249849
# DOS_SLOWHTTPTEST        8678       5.249849
# BOT                     8678       5.249849
# (165300, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49138      67.991310
# PORTSCAN                8479      11.732230
# DOS_HULK                8438      11.675499
# DDOS                    5094       7.048470
# DOS_GOLDENEYE            399       0.552089
# FTP_PATATOR              224       0.309945
# DOS_SLOWLORIS            208       0.287806
# SSH_PATATOR              161       0.222773
# DOS_SLOWHTTPTEST          97       0.134217
# BOT                       33       0.045661
# (72271, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# results_list : 4
# y_pred_bagging : (16993, 10)
# y_pred_RandomForestClassifier : (16993, 10)
# y_pred_DecisionTreeClassifier : (16993, 10)
# y_pred_MLPClassifier : (16993, 10)
# y_pred_KNeighborsClassifier : (16993, 10)
# results_list : 5
#
#     Iteración 9
#
# Modelo RandomForestClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77818      47.058610
# PORTSCAN               13429       8.120873
# DOS_HULK               13371       8.085799
# DDOS                    8678       5.247817
# DOS_GOLDENEYE           8678       5.247817
# SSH_PATATOR             8678       5.247817
# FTP_PATATOR             8678       5.247817
# DOS_SLOWHTTPTEST        8678       5.247817
# DOS_SLOWLORIS           8678       5.247817
# BOT                     8678       5.247817
# (165364, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49148      68.055056
# PORTSCAN                8466      11.722839
# DOS_HULK                8425      11.666067
# DDOS                    5042       6.981639
# DOS_GOLDENEYE            415       0.574649
# FTP_PATATOR              225       0.311557
# DOS_SLOWLORIS            208       0.288017
# SSH_PATATOR              156       0.216013
# DOS_SLOWHTTPTEST          94       0.130161
# BOT                       39       0.054003
# (72218, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo DecisionTreeClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77778      47.045801
# PORTSCAN               13429       8.122838
# DOS_HULK               13371       8.087755
# DDOS                    8678       5.249087
# DOS_SLOWLORIS           8678       5.249087
# FTP_PATATOR             8678       5.249087
# DOS_GOLDENEYE           8678       5.249087
# DOS_SLOWHTTPTEST        8678       5.249087
# SSH_PATATOR             8678       5.249087
# BOT                     8678       5.249087
# (165324, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49078      68.119422
# PORTSCAN                8438      11.711799
# DOS_HULK                8363      11.607701
# DDOS                    5063       7.027357
# DOS_GOLDENEYE            396       0.549641
# DOS_SLOWLORIS            223       0.309520
# FTP_PATATOR              207       0.287312
# SSH_PATATOR              152       0.210973
# DOS_SLOWHTTPTEST          89       0.123530
# BOT                       38       0.052743
# (72047, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo MLPClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77820      47.059250
# PORTSCAN               13429       8.120775
# DOS_HULK               13371       8.085701
# DDOS                    8678       5.247753
# DOS_GOLDENEYE           8678       5.247753
# DOS_SLOWLORIS           8678       5.247753
# BOT                     8678       5.247753
# DOS_SLOWHTTPTEST        8678       5.247753
# SSH_PATATOR             8678       5.247753
# FTP_PATATOR             8678       5.247753
# (165366, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49173      68.010567
# PORTSCAN                8469      11.713369
# DOS_HULK                8446      11.681558
# DDOS                    5084       7.031617
# DOS_GOLDENEYE            403       0.557384
# DOS_SLOWLORIS            220       0.304279
# FTP_PATATOR              215       0.297364
# SSH_PATATOR              160       0.221294
# DOS_SLOWHTTPTEST          92       0.127244
# BOT                       40       0.055324
# (72302, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo KNeighborsClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77823      47.060211
# PORTSCAN               13429       8.120627
# DOS_HULK               13371       8.085554
# DDOS                    8678       5.247658
# FTP_PATATOR             8678       5.247658
# DOS_GOLDENEYE           8678       5.247658
# DOS_SLOWLORIS           8678       5.247658
# SSH_PATATOR             8678       5.247658
# DOS_SLOWHTTPTEST        8678       5.247658
# BOT                     8678       5.247658
# (165369, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49138      67.992251
# PORTSCAN                8479      11.732392
# DOS_HULK                8439      11.677044
# DDOS                    5096       7.051335
# DOS_GOLDENEYE            397       0.549329
# FTP_PATATOR              220       0.304414
# DOS_SLOWLORIS            210       0.290577
# SSH_PATATOR              162       0.224159
# DOS_SLOWHTTPTEST          95       0.131452
# BOT                       34       0.047046
# (72270, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# results_list : 4
# y_pred_bagging : (16992, 10)
# y_pred_RandomForestClassifier : (16992, 10)
# y_pred_DecisionTreeClassifier : (16992, 10)
# y_pred_MLPClassifier : (16992, 10)
# y_pred_KNeighborsClassifier : (16992, 10)
# results_list : 5
#
#     Iteración 10
#
# Modelo RandomForestClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77767      47.042277
# PORTSCAN               13428       8.122773
# DOS_HULK               13372       8.088898
# DDOS                    8678       5.249436
# DOS_GOLDENEYE           8678       5.249436
# DOS_SLOWLORIS           8678       5.249436
# FTP_PATATOR             8678       5.249436
# SSH_PATATOR             8678       5.249436
# DOS_SLOWHTTPTEST        8678       5.249436
# BOT                     8678       5.249436
# (165313, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49148      68.047518
# PORTSCAN                8467      11.722925
# DOS_HULK                8427      11.667544
# DDOS                    5042       6.980866
# DOS_GOLDENEYE            416       0.575970
# FTP_PATATOR              224       0.310138
# DOS_SLOWLORIS            209       0.289369
# SSH_PATATOR              156       0.215989
# DOS_SLOWHTTPTEST          98       0.135685
# BOT                       39       0.053997
# (72226, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo DecisionTreeClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77788      47.049004
# PORTSCAN               13428       8.121741
# DOS_HULK               13372       8.087871
# DDOS                    8678       5.248769
# DOS_SLOWLORIS           8678       5.248769
# FTP_PATATOR             8678       5.248769
# DOS_GOLDENEYE           8678       5.248769
# DOS_SLOWHTTPTEST        8678       5.248769
# SSH_PATATOR             8678       5.248769
# BOT                     8678       5.248769
# (165334, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49078      68.119422
# PORTSCAN                8438      11.711799
# DOS_HULK                8363      11.607701
# DDOS                    5063       7.027357
# DOS_GOLDENEYE            396       0.549641
# DOS_SLOWLORIS            223       0.309520
# FTP_PATATOR              207       0.287312
# SSH_PATATOR              152       0.210973
# DOS_SLOWHTTPTEST          89       0.123530
# BOT                       38       0.052743
# (72047, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo MLPClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77786      47.048363
# PORTSCAN               13428       8.121840
# DOS_HULK               13372       8.087968
# DDOS                    8678       5.248833
# FTP_PATATOR             8678       5.248833
# DOS_GOLDENEYE           8678       5.248833
# BOT                     8678       5.248833
# DOS_SLOWHTTPTEST        8678       5.248833
# DOS_SLOWLORIS           8678       5.248833
# SSH_PATATOR             8678       5.248833
# (165332, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49173      68.010567
# PORTSCAN                8468      11.711986
# DOS_HULK                8447      11.682941
# DDOS                    5084       7.031617
# DOS_GOLDENEYE            403       0.557384
# DOS_SLOWLORIS            220       0.304279
# FTP_PATATOR              215       0.297364
# SSH_PATATOR              160       0.221294
# DOS_SLOWHTTPTEST          92       0.127244
# BOT                       40       0.055324
# (72302, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# Modelo KNeighborsClassifier
# Conjunto de entrenamiento
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 77761      47.040355
# PORTSCAN               13428       8.123068
# DOS_HULK               13372       8.089192
# DDOS                    8678       5.249626
# DOS_SLOWLORIS           8678       5.249626
# FTP_PATATOR             8678       5.249626
# DOS_GOLDENEYE           8678       5.249626
# SSH_PATATOR             8678       5.249626
# BOT                     8678       5.249626
# DOS_SLOWHTTPTEST        8678       5.249626
# (165307, 22)
# Conjunto de validación
#                   Frecuencia  Frecuencia(%)
# label
# BENIGN                 49138      67.991310
# PORTSCAN                8479      11.732230
# DOS_HULK                8439      11.676883
# DDOS                    5096       7.051238
# DOS_GOLDENEYE            398       0.550705
# FTP_PATATOR              220       0.304410
# DOS_SLOWLORIS            209       0.289189
# SSH_PATATOR              163       0.225540
# DOS_SLOWHTTPTEST          95       0.131450
# BOT                       34       0.047045
# (72271, 22)
# Entrenamiento
# Validación
# Prueba del metamodelo Bagging
# Registro de resultados
# results_list : 4
# y_pred_bagging : (16992, 10)
# y_pred_RandomForestClassifier : (16992, 10)
# y_pred_DecisionTreeClassifier : (16992, 10)
# y_pred_MLPClassifier : (16992, 10)
# y_pred_KNeighborsClassifier : (16992, 10)
# results_list : 5

# %%
df_validation
# Out:
#              iter                   model             label     TP     TN  FP  \
# 0     Iteración 1  RandomForestClassifier            BENIGN  49113  23050  21
# 1     Iteración 1  RandomForestClassifier               BOT     38  72180   0
# 2     Iteración 1  RandomForestClassifier              DDOS   5042  67175   2
# 3     Iteración 1  RandomForestClassifier     DOS_GOLDENEYE    402  71801   2
# 4     Iteración 1  RandomForestClassifier          DOS_HULK   8423  63794   0
# ..            ...                     ...               ...    ...    ...  ..
# 395  Iteración 10    KNeighborsClassifier  DOS_SLOWHTTPTEST     91  72169   7
# 396  Iteración 10    KNeighborsClassifier     DOS_SLOWLORIS    203  72039  23
# 397  Iteración 10    KNeighborsClassifier       FTP_PATATOR    219  72051   0
# 398  Iteración 10    KNeighborsClassifier          PORTSCAN   8466  63761  31
# 399  Iteración 10    KNeighborsClassifier       SSH_PATATOR    163  72106   2
#
#      FN    AUC_SP         ms
# 0    35  0.999962   0.356037
# 1     1  1.000000   0.356037
# 2     0  0.999998   0.356037
# 3    14  0.997974   0.356037
# 4     2  0.999993   0.356037
# ..   ..       ...        ...
# 395   4  0.955305  13.982771
# 396   6  0.964386  13.982771
# 397   1  0.997714  13.982771
# 398  13  0.998127  13.982771
# 399   0  0.993939  13.982771
#
# [400 rows x 9 columns]

# %%
df_testing
# Out:
#              iter                   model             label     TP     TN  FP  \
# 0     Iteración 1  RandomForestClassifier            BENIGN  11564   5416   6
# 1     Iteración 1  RandomForestClassifier               BOT      9  16984   0
# 2     Iteración 1  RandomForestClassifier              DDOS   1189  15804   0
# 3     Iteración 1  RandomForestClassifier     DOS_GOLDENEYE     91  16897   2
# 4     Iteración 1  RandomForestClassifier          DOS_HULK   1979  15012   0
# ..            ...                     ...               ...    ...    ...  ..
# 495  Iteración 10       BaggingClassifier  DOS_SLOWHTTPTEST     21  16970   0
# 496  Iteración 10       BaggingClassifier     DOS_SLOWLORIS     49  16940   2
# 497  Iteración 10       BaggingClassifier       FTP_PATATOR     50  16942   0
# 498  Iteración 10       BaggingClassifier          PORTSCAN   1989  14995   7
# 499  Iteración 10       BaggingClassifier       SSH_PATATOR     37  16955   0
#
#      FN      Exac      Prec      Sens        F1    AUC_SP         ms
# 0     7  0.999235  0.999481  0.999395  0.999438  0.999894   0.081429
# 1     0  1.000000  1.000000  1.000000  1.000000  1.000000   0.081429
# 2     0  1.000000  1.000000  1.000000  1.000000  1.000000   0.081429
# 3     3  0.999706  0.978495  0.968085  0.973262  0.998891   0.081429
# 4     2  0.999882  1.000000  0.998990  0.999495  0.999733   0.081429
# ..   ..       ...       ...       ...       ...       ...        ...
# 495   1  0.999941  1.000000  0.954545  0.976744  0.990079  43.372202
# 496   1  0.999823  0.960784  0.980000  0.970297  0.997838  43.372202
# 497   0  1.000000  1.000000  1.000000  1.000000  1.000000  43.372202
# 498   1  0.999529  0.996493  0.999497  0.997993  0.999539  43.372202
# 499   0  1.000000  1.000000  1.000000  1.000000  1.000000  43.372202
#
# [500 rows x 13 columns]

# %%
df_validation.to_excel("output/validation_results.xlsx")
df_testing.to_excel("output/testing_results.xlsx")
print("Guardado")
# Out:
# Guardado
